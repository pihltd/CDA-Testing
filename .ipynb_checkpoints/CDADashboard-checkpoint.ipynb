# %%
from cdapython import unique_terms
import requests
import pprint
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import math

# %%
def goPie(project, catdata):
    catlist = []
    countlist = []
    for category, count in catdata.items():
        catlist.append(category)
        countlist.append(count)
    fig = go.Pie(labels=catlist, values=countlist, title_text=project, textinfo='value')
    return fig

# %%
def pexPie(project, catdata):
    #Expects an list of {datacategory:count}
    catlist = []
    countlist = []
    for category,count in catdata.items():
        catlist.append(category)
        countlist.append(count)
    fig = px.pie(values=countlist, names=catlist, title = project)
    return fig

# %%
def plotlySubplots(jsondata, cols, rows, height, title):
    #Need to have a specs row for each row in the subplot and each row has to define each column
    collist = []
    x = 1
    while x <= cols:
        collist.append({'type': 'pie'})
        x += 1
    speclist =[]
    x = 1
    while x<= rows:
        speclist.append(collist)
        x +=1

    subfig = make_subplots(rows=rows, cols=cols, specs=speclist)
    tempcol = 1
    temprow = 1
    for project,data in jsondata.items():
        if data:
            fig = goPie(project, data)
            subfig.add_trace(fig,row = temprow, col = tempcol)  
            if tempcol == cols:
                tempcol = 1
                temprow = temprow + 1
            else:
                tempcol = tempcol + 1
        subfig.update_layout(height= height, title_text=title)
    return subfig

# %%
def getProjects(testmode):
    if testmode:
        projectlist = ["TCGA-UCS", "TCGA-OV", "TCGA-GBM","TCGA-KICH", "TCGA-KIRC", "TCGA-BRCA"]
        #projectlist = ["TCGA-BRCA"]
    else:
        projectlist = unique_terms("ResearchSubject.associated_project")
        #projectquery = """SELECT DISTINCT(_project) FROM gdc-bq-sample.cda_mvp.v3, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File) AS _File, UNNEST(_File.associated_project) as _project"""
        #resultsid = runNewAPIQuery(projectquery, None)
        #projresults = getResults(resultsid,0,100)
        #projectlist = []
        #for projresult in projresults['result']:
        #    projectlist.append(projresult['_project'])
    return projectlist

# %%
def runAPIQuery(querystring, limit):
    #Using a limit:
    if limit is not None:
        cdaURL = "https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3?limit={}".format(str(limit))
    else:
        cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3'
    headers = {'accept' : 'application/json', 'Content-Type' : 'text/plain'}

    request = requests.post(cdaURL, headers = headers, data = querystring)

    if request.status_code == 200:
        return request.json()
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code,query))

# %%
def runNewAPIQuery(querystring,limit):
    #Due to a change in the API, queries now return a query ID, not the result.
    if limit is not None:
        cdaURL = "https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3?limit={}".format(str(limit))
    else:
        #cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3'
        cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query'
    headers = {'accept' : 'application/json', 'Content-Type' : 'text/plain'}

    request = requests.post(cdaURL, headers = headers, data = querystring)

    if request.status_code == 200:
        result = request.json()
        query_id = result['query_id']
        return query_id
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code))

# %%
def getResults(queryid, offset, limit):
    #curl -X GET "https://cda.cda-dev.broadinstitute.org/api/v1/query/bcff531e-0ada-4d43-9d81-ae9ab05efacb?offset=10&limit=100" -H "accept: application/json"
    resultURL = "https://cda.cda-dev.broadinstitute.org/api/v1/query/{}?offset={}&limit={}".format(queryid, str(offset), str(limit))
    #pprint.pprint(resultURL)
    headers = {'accept' : 'application/json'}
    
    request = requests.get(resultURL, headers = headers)
    
    if request.status_code == 200:
        #pprint.pprint(request.json())
        return request.json()
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code))

# %%
def samplePerDataCategory(project):
    querystring = """SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3, 
        UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File) 
        AS _File, UNNEST(_File.associated_project) as _project WHERE _project= '{}' GROUP BY _File.data_category""".format(project)
    return querystring

# %%
def parseSamplePerDataCategory(results):
    finaldata = {}
    #finaldata['next_url'] = str(results['next_url'])
    for result in results['result']:
        finaldata[result['data_category']] = result['spec_count']
    return finaldata

# %%
projectlist = getProjects(False)
#projectlist = getProjects(True)
pprint.pprint(projectlist)
#projectcount = len(projectlist)
countdata = {}
resultsets = {}
for project in projectlist:
    querystring = samplePerDataCategory(project)
    try:
        apiresults = runNewAPIQuery(querystring, None)
        resultsets[project] = apiresults
    except Exception as e:
        pprint.pprint(e)
#pprint.pprint(resultsets)
pprint.pprint("Completed")
# Out:
# ['TARGET-OS',
#  'TARGET-NBL',
#  'TARGET-ALL-P3',
#  'TARGET-AML',
#  'TCGA-GBM',
#  'TCGA-DLBC',
#  'TCGA-OV',
#  'TCGA-LUAD',
#  'TCGA-LGG',
#  'TCGA-BRCA',
#  'TCGA-CHOL',
#  'TCGA-TGCT',
#  'TCGA-UCEC',
#  'TARGET-ALL-P1',
#  'CPTAC-3',
#  'CPTAC3-Discovery',
#  'GENIE-MSK',
#  'GENIE-DFCI',
#  'GENIE-GRCC',
#  'GENIE-JHU',
#  'GENIE-MDA',
#  'GENIE-NKI',
#  'GENIE-UHN',
#  'GENIE-VICC',
#  'FM-AD',
#  'TCGA-THCA',
#  'VAREPOP-APOLLO',
#  'TCGA-PAAD',
#  'CGCI-HTMCP-CC',
#  'TCGA-LUSC',
#  'TCGA-BLCA',
#  'TCGA-CESC',
#  'TCGA-ESCA',
#  'TCGA-HNSC',
#  'TCGA-READ',
#  'TCGA-COAD',
#  'CPTAC-2',
#  'HCMI-CMDC',
#  'TCGA-PRAD',
#  'TCGA-STAD',
#  'CPTAC-TCGA',
#  'WCDT-MCRPC',
#  'TCGA-LIHC',
#  'TCGA-KIRP',
#  'TCGA-KIRC',
#  'TCGA-KICH',
#  'TCGA-ACC',
#  'TCGA-THYM',
#  'TCGA-PCPG',
#  'TCGA-SKCM',
#  'TCGA-UVM',
#  'TCGA-SARC',
#  'TCGA-UCS',
#  'TARGET-WT',
#  'TARGET-RT',
#  'TARGET-CCSK',
#  'TCGA-MESO',
#  'Proteogenomic Analysis of Pediatric Brain Cancer Tumors Pilot Study',
#  'CGCI-BLGSP',
#  'CTSP-DLBCL1',
#  'BEATAML1.0-COHORT',
#  'MMRF-COMMPASS',
#  'TARGET-ALL-P2',
#  'TCGA-LAML',
#  'BEATAML1.0-CRENOLANIB',
#  'OHSU-CNL',
#  'ORGANOID-PANCREATIC',
#  'Integrated Proteogenomic Characterization of HBV-related Hepatocellular '
#  'carcinoma',
#  'Human Early-Onset Gastric Cancer - Korea University',
#  'CPTAC2 Retrospective',
#  'CMI-MBC',
#  'CMI-ASC',
#  'CMI-MPC',
#  'PJ25730263',
#  'NCICCR-DLBCL',
#  'Academia Sinica LUAD-100',
#  'Georgetown Lung Cancer Proteomics Study',
#  'Oral Squamous Cell Carcinoma - Chang Gung University']
# {'Academia Sinica LUAD-100': 'b28d1259-cbad-42eb-99de-5a2bf9d119be',
#  'BEATAML1.0-COHORT': 'd65c2ec8-ba4a-4dae-a154-0bb43f6e9685',
#  'BEATAML1.0-CRENOLANIB': '30f76065-adfe-4095-8f22-a3f243d61a94',
#  'CGCI-BLGSP': 'c8512a80-a916-4877-869e-2093135140ce',
#  'CGCI-HTMCP-CC': 'ae05293a-d034-4899-9ac4-b4ac0e4dbc00',
#  'CMI-ASC': '3ab444d2-156a-44ea-a296-56b8817697ec',
#  'CMI-MBC': '7acc3a88-bbf7-4885-8ea9-0014f5d2d9f6',
#  'CMI-MPC': 'f5b65180-ea50-43df-a89d-9f0163162769',
#  'CPTAC-2': 'a8e87a1e-f21a-4557-95b9-add0466c4b1e',
#  'CPTAC-3': '095000b7-72c9-4a48-b6c0-6e9186e51cf5',
#  'CPTAC-TCGA': '50b0680f-108d-4f51-b36c-522814b69085',
#  'CPTAC2 Retrospective': 'b656b9bb-2045-42e7-8dfb-3d4edfca88a9',
#  'CPTAC3-Discovery': 'e2e95aa5-097f-40b0-9588-2ebaa723de15',
#  'CTSP-DLBCL1': '03297ce8-dfb9-4c66-a183-05282435e08e',
#  'FM-AD': '1ca40e9e-1529-4333-bdda-20f01ae61f18',
#  'GENIE-DFCI': 'b0b6f4fe-10cb-452a-8158-deb92928d860',
#  'GENIE-GRCC': '6e652f15-ac09-48f4-94f6-66118fdee5d3',
#  'GENIE-JHU': 'cbd38e5f-c898-4416-b584-d1dff551cffc',
#  'GENIE-MDA': '8e878d99-4a77-45cc-a609-4361e32e90f9',
#  'GENIE-MSK': 'd059f0fd-070e-4d5e-9100-41c0a14aad62',
#  'GENIE-NKI': 'da626bf9-5dca-4052-862b-81e048fa1e8c',
#  'GENIE-UHN': 'a9720a24-51d6-4589-9687-21e4c1a64e96',
#  'GENIE-VICC': '5e114aa0-c41d-45c9-9612-4ad2101e6ae1',
#  'Georgetown Lung Cancer Proteomics Study': 'c72d9896-1f93-4e07-9ffb-ef076fd80d9a',
#  'HCMI-CMDC': '4f79f6c0-4889-4cd3-9d30-7522d1d194f7',
#  'Human Early-Onset Gastric Cancer - Korea University': '1b5c45d9-4196-4c39-baa1-6a97eb2ce361',
#  'Integrated Proteogenomic Characterization of HBV-related Hepatocellular carcinoma': 'c0e76bf9-51a9-4af2-9e3b-f0a1a15e072f',
#  'MMRF-COMMPASS': '6b609d1b-ba49-4b0f-b126-7ad05628d955',
#  'NCICCR-DLBCL': '11b9abf1-3b26-4972-8ae6-d6899f7cbec3',
#  'OHSU-CNL': 'b9c6664d-35f0-4c9b-b279-9c15b94ff5dc',
#  'ORGANOID-PANCREATIC': 'a26a7a67-037e-42b6-8011-248dafe04794',
#  'Oral Squamous Cell Carcinoma - Chang Gung University': 'ed98b99a-61da-48d8-9882-aa84f0df204e',
#  'PJ25730263': '991caab1-5275-498a-b00f-b84b75c17c4f',
#  'Proteogenomic Analysis of Pediatric Brain Cancer Tumors Pilot Study': '57a93135-9733-479a-bc98-3cdb4ff7a956',
#  'TARGET-ALL-P1': 'ed5c202b-2080-4e6b-97a6-a9bddbd2caa8',
#  'TARGET-ALL-P2': 'dd0d5fe1-fd87-4744-a008-7ac1e6570297',
#  'TARGET-ALL-P3': '9ecc3ceb-58f2-4482-b05e-6e5c6dda0151',
#  'TARGET-AML': 'e565db72-125b-4d57-8eb1-4994975429ed',
#  'TARGET-CCSK': 'a328aa57-e93e-4e65-888e-83439c409373',
#  'TARGET-NBL': '5be7d337-bbdc-4eb8-bf88-c6870a3c34af',
#  'TARGET-OS': 'b423d274-31a3-473a-8622-88b7d53e74c8',
#  'TARGET-RT': '8558b9b8-f025-4b38-916e-c9535016b2e6',
#  'TARGET-WT': 'eddbfe1f-92b7-414d-8dfc-6c0c437456c7',
#  'TCGA-ACC': 'd66ee2da-5d60-490d-9053-d78020bbbd45',
#  'TCGA-BLCA': 'd0029091-5e2e-4f88-b9c2-1fc77f7ff38d',
#  'TCGA-BRCA': '3f05e8b9-7e85-4f85-ae00-9df3db8a3661',
#  'TCGA-CESC': '2a17271b-3273-427b-afdd-40104f9d4391',
#  'TCGA-CHOL': 'e1b1d083-4e13-459c-b9ce-92f25a7d4b9e',
#  'TCGA-COAD': '212a1d54-5c15-4a31-aed5-4426bda43c4d',
#  'TCGA-DLBC': '66334a10-75e4-473c-af39-3349cc51dba0',
#  'TCGA-ESCA': 'e8f673e1-36ac-4684-ac08-3f758f474cc4',
#  'TCGA-GBM': '95f25d6d-5fb5-4bc6-9237-5a52b222ccb9',
#  'TCGA-HNSC': '98db3a1e-6e90-4036-9271-02c1b35ee993',
#  'TCGA-KICH': '2c0b3443-97de-4223-be12-7e2da764eceb',
#  'TCGA-KIRC': '5e054f52-968c-4048-8c14-c54560cfee55',
#  'TCGA-KIRP': 'b65482b1-6bc5-4990-84a9-ba7e43b2d1f2',
#  'TCGA-LAML': '65e72988-540c-4f73-9726-e27550209126',
#  'TCGA-LGG': 'f528e583-99e5-4166-84ec-4e06de043c48',
#  'TCGA-LIHC': '11de86e9-31dd-4327-85df-bbf792c6a0b2',
#  'TCGA-LUAD': '1e1baa04-b5a3-420b-a99c-1b7ec7176066',
#  'TCGA-LUSC': 'f9d4f792-7b05-4860-a147-8f8df92e63c1',
#  'TCGA-MESO': 'a9947b19-3cc3-4509-a8f1-0122ad403e12',
#  'TCGA-OV': '6f257f6c-9b9b-4534-be68-8e398a09a057',
#  'TCGA-PAAD': 'c5084992-57b3-422c-8343-3053d560a6cb',
#  'TCGA-PCPG': '39a1df85-d288-4aab-ab71-2b0b42ccfdfe',
#  'TCGA-PRAD': 'dcaa856f-867f-4815-a673-6c3d9e59e452',
#  'TCGA-READ': '8e419b7b-ffb5-4f7b-a72f-09435df79ae7',
#  'TCGA-SARC': 'cf098529-3dde-4fbc-9b3b-b5196c5eec9d',
#  'TCGA-SKCM': '25e42064-6622-4ce7-ab14-70e49aef73ff',
#  'TCGA-STAD': '689c12ca-0a50-4cb3-8cdd-b41a99307628',
#  'TCGA-TGCT': '0ba89a7c-32e1-4a7f-b238-4160c75c5cec',
#  'TCGA-THCA': '3482b241-b6bc-41fd-b569-581927dfca9c',
#  'TCGA-THYM': '7a89a8a0-5400-408f-be32-9ca791305412',
#  'TCGA-UCEC': '1dab6427-6fb1-4986-8095-563931137e77',
#  'TCGA-UCS': 'bdcec932-f12f-4748-a6b1-4db47da23906',
#  'TCGA-UVM': 'e7b2f370-c4ac-4d41-a062-d2c35f6fb218',
#  'VAREPOP-APOLLO': 'c99acd84-850f-465b-b104-dc24163e4f5a',
#  'WCDT-MCRPC': 'd4baa3b0-7cbe-48a4-9974-61ccfa760961'}

# %%
for disease, resultid in resultsets.items():
    try:
        results = getResults(resultid,0,10)
        parsedresults = parseSamplePerDataCategory(results)
        #pprint.pprint(parsedresults)
        countdata[disease] = parsedresults
    except Exception as e:
        pprint.pprint(e)
pprint.pprint("Completed")
# Out:
# {'Combined Nucleotide Variation': '62',
#  'Copy Number Variation': '162',
#  'Sequencing Reads': '224',
#  'Simple Nucleotide Variation': '194',
#  'Structural Variation': '88',
#  'Transcriptome Profiling': '88'}
# {'Sequencing Reads': '511',
#  'Simple Nucleotide Variation': '438',
#  'Structural Variation': '161',
#  'Transcriptome Profiling': '161'}
# {'Sequencing Reads': '397',
#  'Simple Nucleotide Variation': '225',
#  'Structural Variation': '135',
#  'Transcriptome Profiling': '135'}
# {'Combined Nucleotide Variation': '494',
#  'Copy Number Variation': '165',
#  'Sequencing Reads': '1988',
#  'Simple Nucleotide Variation': '61',
#  'Transcriptome Profiling': '1905'}
# {'Biospecimen': '1008',
#  'Copy Number Variation': '1146',
#  'DNA Methylation': '438',
#  'Sequencing Reads': '816',
#  'Simple Nucleotide Variation': '804',
#  'Transcriptome Profiling': '173'}
# {'Biospecimen': '90',
#  'Copy Number Variation': '100',
#  'DNA Methylation': '48',
#  'Sequencing Reads': '85',
#  'Simple Nucleotide Variation': '74',
#  'Transcriptome Profiling': '48'}
# {'Biospecimen': '810',
#  'Copy Number Variation': '1191',
#  'DNA Methylation': '623',
#  'Sequencing Reads': '1035',
#  'Simple Nucleotide Variation': '886',
#  'Transcriptome Profiling': '501'}
# {'Biospecimen': '1197',
#  'Copy Number Variation': '1124',
#  'DNA Methylation': '647',
#  'Sequencing Reads': '1222',
#  'Simple Nucleotide Variation': '1156',
#  'Transcriptome Profiling': '617'}
# {'Biospecimen': '1028',
#  'Copy Number Variation': '1043',
#  'DNA Methylation': '534',
#  'Sequencing Reads': '1048',
#  'Simple Nucleotide Variation': '1043',
#  'Transcriptome Profiling': '534'}
# {'Biospecimen': '2336',
#  'Copy Number Variation': '2254',
#  'DNA Methylation': '1232',
#  'Sequencing Reads': '2237',
#  'Simple Nucleotide Variation': '2106',
#  'Transcriptome Profiling': '1230'}
# {'Biospecimen': '110',
#  'Copy Number Variation': '85',
#  'DNA Methylation': '45',
#  'Sequencing Reads': '115',
#  'Simple Nucleotide Variation': '102',
#  'Transcriptome Profiling': '45'}
# {'Biospecimen': '310',
#  'Copy Number Variation': '306',
#  'DNA Methylation': '156',
#  'Sequencing Reads': '306',
#  'Simple Nucleotide Variation': '306',
#  'Transcriptome Profiling': '156'}
# {'Biospecimen': '1111',
#  'Copy Number Variation': '1121',
#  'DNA Methylation': '599',
#  'Sequencing Reads': '1123',
#  'Simple Nucleotide Variation': '1089',
#  'Transcriptome Profiling': '587'}
# {'Sequencing Reads': '23',
#  'Structural Variation': '12',
#  'Transcriptome Profiling': '12'}
# {'Copy Number Variation': '1885',
#  'Sequencing Reads': '2361',
#  'Simple Nucleotide Variation': '1897',
#  'Somatic Structural Variation': '1885',
#  'Structural Variation': '1496',
#  'Transcriptome Profiling': '1496'}
# {'Peptide Spectral Matches': '1358',
#  'Processed Mass Spectra': '1358',
#  'Raw Mass Spectra': '1358'}
# {'Copy Number Variation': '16823',
#  'Simple Nucleotide Variation': '16823',
#  'Somatic Structural Variation': '2824'}
# {'Copy Number Variation': '14232', 'Simple Nucleotide Variation': '14232'}
# {'Simple Nucleotide Variation': '1038'}
# {'Simple Nucleotide Variation': '3320'}
# {'Simple Nucleotide Variation': '3857'}
# {'Simple Nucleotide Variation': '801'}
# {'Simple Nucleotide Variation': '2632'}
# {'Copy Number Variation': '1473',
#  'Simple Nucleotide Variation': '2052',
#  'Somatic Structural Variation': '308'}
# {'Simple Nucleotide Variation': '18004'}
# {'Biospecimen': '1117',
#  'Copy Number Variation': '1040',
#  'DNA Methylation': '571',
#  'Sequencing Reads': '1045',
#  'Simple Nucleotide Variation': '1000',
#  'Transcriptome Profiling': '574'}
# {'Sequencing Reads': '7', 'Simple Nucleotide Variation': '7'}
# {'Biospecimen': '412',
#  'Copy Number Variation': '376',
#  'DNA Methylation': '195',
#  'Sequencing Reads': '376',
#  'Simple Nucleotide Variation': '367',
#  'Transcriptome Profiling': '183'}
# {'Copy Number Variation': '274',
#  'Sequencing Reads': '456',
#  'Simple Nucleotide Variation': '442',
#  'Somatic Structural Variation': '274',
#  'Structural Variation': '161',
#  'Transcriptome Profiling': '161'}
# {'Biospecimen': '1199',
#  'Copy Number Variation': '1063',
#  'DNA Methylation': '572',
#  'Sequencing Reads': '1061',
#  'Simple Nucleotide Variation': '1000',
#  'Transcriptome Profiling': '560'}
# {'Biospecimen': '839',
#  'Copy Number Variation': '840',
#  'DNA Methylation': '437',
#  'Sequencing Reads': '846',
#  'Simple Nucleotide Variation': '828',
#  'Transcriptome Profiling': '435'}
# {'Biospecimen': '585',
#  'Copy Number Variation': '609',
#  'DNA Methylation': '312',
#  'Sequencing Reads': '617',
#  'Simple Nucleotide Variation': '612',
#  'Transcriptome Profiling': '312'}
# {'Biospecimen': '405',
#  'Copy Number Variation': '377',
#  'DNA Methylation': '202',
#  'Sequencing Reads': '376',
#  'Simple Nucleotide Variation': '369',
#  'Transcriptome Profiling': '198'}
# {'Biospecimen': '1029',
#  'Copy Number Variation': '1104',
#  'DNA Methylation': '580',
#  'Sequencing Reads': '1120',
#  'Simple Nucleotide Variation': '1022',
#  'Transcriptome Profiling': '574'}
# {'Biospecimen': '355',
#  'Copy Number Variation': '341',
#  'DNA Methylation': '178',
#  'Sequencing Reads': '343',
#  'Simple Nucleotide Variation': '316',
#  'Transcriptome Profiling': '178'}
# {'Biospecimen': '1017',
#  'Copy Number Variation': '980',
#  'DNA Methylation': '547',
#  'Sequencing Reads': '960',
#  'Simple Nucleotide Variation': '879',
#  'Transcriptome Profiling': '515'}
# {'Peptide Spectral Matches': '540',
#  'Processed Mass Spectra': '540',
#  'Raw Mass Spectra': '540',
#  'Sequencing Reads': '713',
#  'Simple Nucleotide Variation': '656',
#  'Transcriptome Profiling': '341'}
# {'Copy Number Variation': '191',
#  'Sequencing Reads': '200',
#  'Simple Nucleotide Variation': '197',
#  'Somatic Structural Variation': '191',
#  'Structural Variation': '122',
#  'Transcriptome Profiling': '126'}
# {'Biospecimen': '1017',
#  'Copy Number Variation': '1054',
#  'DNA Methylation': '553',
#  'Sequencing Reads': '1058',
#  'Simple Nucleotide Variation': '1001',
#  'Transcriptome Profiling': '555'}
# {'Biospecimen': '952',
#  'Copy Number Variation': '934',
#  'DNA Methylation': '470',
#  'Sequencing Reads': '933',
#  'Simple Nucleotide Variation': '882',
#  'Transcriptome Profiling': '480'}
# {'Peptide Spectral Matches': '371',
#  'Processed Mass Spectra': '371',
#  'Raw Mass Spectra': '371'}
# {'Sequencing Reads': '202', 'Transcriptome Profiling': '99'}
# {'Biospecimen': '834',
#  'Copy Number Variation': '786',
#  'DNA Methylation': '430',
#  'Sequencing Reads': '792',
#  'Simple Nucleotide Variation': '753',
#  'Transcriptome Profiling': '429'}
# {'Biospecimen': '651',
#  'Copy Number Variation': '606',
#  'DNA Methylation': '342',
#  'Sequencing Reads': '613',
#  'Simple Nucleotide Variation': '577',
#  'Transcriptome Profiling': '326'}
# {'Biospecimen': '1497',
#  'Copy Number Variation': '1083',
#  'DNA Methylation': '894',
#  'Sequencing Reads': '899',
#  'Simple Nucleotide Variation': '681',
#  'Transcriptome Profiling': '611'}
# {'Biospecimen': '305',
#  'Copy Number Variation': '132',
#  'DNA Methylation': '66',
#  'Sequencing Reads': '132',
#  'Simple Nucleotide Variation': '132',
#  'Transcriptome Profiling': '91'}
# {'Biospecimen': '152',
#  'Copy Number Variation': '182',
#  'DNA Methylation': '80',
#  'Sequencing Reads': '184',
#  'Simple Nucleotide Variation': '184',
#  'Transcriptome Profiling': '80'}
# {'Biospecimen': '258',
#  'Copy Number Variation': '250',
#  'DNA Methylation': '126',
#  'Sequencing Reads': '249',
#  'Simple Nucleotide Variation': '246',
#  'Transcriptome Profiling': '126'}
# {'Biospecimen': '367',
#  'Copy Number Variation': '365',
#  'DNA Methylation': '187',
#  'Sequencing Reads': '366',
#  'Simple Nucleotide Variation': '363',
#  'Transcriptome Profiling': '187'}
# {'Biospecimen': '910',
#  'Copy Number Variation': '943',
#  'DNA Methylation': '475',
#  'Sequencing Reads': '945',
#  'Simple Nucleotide Variation': '942',
#  'Transcriptome Profiling': '474'}
# {'Biospecimen': '158',
#  'Copy Number Variation': '160',
#  'DNA Methylation': '80',
#  'Sequencing Reads': '160',
#  'Simple Nucleotide Variation': '160',
#  'Transcriptome Profiling': '80'}
# {'Biospecimen': '542',
#  'Copy Number Variation': '525',
#  'DNA Methylation': '269',
#  'Sequencing Reads': '524',
#  'Simple Nucleotide Variation': '514',
#  'Transcriptome Profiling': '267'}
# {'Biospecimen': '120',
#  'Copy Number Variation': '112',
#  'DNA Methylation': '57',
#  'Sequencing Reads': '114',
#  'Simple Nucleotide Variation': '114',
#  'Transcriptome Profiling': '57'}
# {'Combined Nucleotide Variation': '162',
#  'Sequencing Reads': '185',
#  'Simple Nucleotide Variation': '82',
#  'Structural Variation': '136',
#  'Transcriptome Profiling': '139'}
# {'Sequencing Reads': '126',
#  'Structural Variation': '70',
#  'Transcriptome Profiling': '72'}
# {'Combined Nucleotide Variation': '26',
#  'Copy Number Variation': '22',
#  'Sequencing Reads': '13',
#  'Structural Variation': '13',
#  'Transcriptome Profiling': '13'}
# {'Biospecimen': '163',
#  'Copy Number Variation': '174',
#  'DNA Methylation': '87',
#  'Sequencing Reads': '170',
#  'Simple Nucleotide Variation': '166',
#  'Transcriptome Profiling': '87'}
# {'Peptide Spectral Matches': '227',
#  'Processed Mass Spectra': '227',
#  'Raw Mass Spectra': '227'}
# {'Copy Number Variation': '148',
#  'Sequencing Reads': '196',
#  'Simple Nucleotide Variation': '148',
#  'Somatic Structural Variation': '148',
#  'Structural Variation': '113',
#  'Transcriptome Profiling': '113'}
# {'Sequencing Reads': '45', 'Transcriptome Profiling': '41'}
# {'Sequencing Reads': '1481',
#  'Simple Nucleotide Variation': '736',
#  'Transcriptome Profiling': '510'}
# {'Sequencing Reads': '2119',
#  'Simple Nucleotide Variation': '2051',
#  'Transcriptome Profiling': '859'}
# {'Copy Number Variation': '587',
#  'Sequencing Reads': '1866',
#  'Simple Nucleotide Variation': '1456',
#  'Structural Variation': '519',
#  'Transcriptome Profiling': '527'}
# {'Copy Number Variation': '399',
#  'DNA Methylation': '140',
#  'Sequencing Reads': '423',
#  'Simple Nucleotide Variation': '313',
#  'Transcriptome Profiling': '193'}
# {'Sequencing Reads': '119', 'Simple Nucleotide Variation': '103'}
# {'Sequencing Reads': '238', 'Transcriptome Profiling': '80'}
# {'Sequencing Reads': '188',
#  'Simple Nucleotide Variation': '65',
#  'Transcriptome Profiling': '55'}
# {'Peptide Spectral Matches': '331',
#  'Processed Mass Spectra': '331',
#  'Raw Mass Spectra': '331'}
# {'Peptide Spectral Matches': '160',
#  'Processed Mass Spectra': '160',
#  'Raw Mass Spectra': '160'}
# {}
# {'Sequencing Reads': '613',
#  'Simple Nucleotide Variation': '404',
#  'Transcriptome Profiling': '203'}
# {'Sequencing Reads': '82',
#  'Simple Nucleotide Variation': '82',
#  'Transcriptome Profiling': '9'}
# {'Sequencing Reads': '60', 'Simple Nucleotide Variation': '60'}
# {'Raw Mass Spectra': '18'}
# {'Sequencing Reads': '489', 'Transcriptome Profiling': '481'}
# {'Raw Mass Spectra': '218'}
# {'Raw Mass Spectra': '21'}
# {'Processed Mass Spectra': '77', 'Raw Mass Spectra': '77'}

# %%
cols = 3
rows = math.ceil(projectcount/cols)
height =300*rows
title = 'Samples in Data Category'
plotlySubplots(countdata, cols, rows, height,title)
