# %%
from cdapython import unique_terms, Q
import requests
import pprint
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import math

# %%
def goPie(project, catdata):
    catlist = []
    countlist = []
    for category, count in catdata.items():
        catlist.append(category)
        countlist.append(count)
    fig = go.Pie(labels=catlist, values=countlist, title_text=project, textinfo='value')
    return fig

# %%
def pexPie(project, catdata):
    #Expects an list of {datacategory:count}
    catlist = []
    countlist = []
    for category,count in catdata.items():
        catlist.append(category)
        countlist.append(count)
    fig = px.pie(values=countlist, names=catlist, title = project)
    return fig

# %%
def plotlySubplots(jsondata, cols, rows, height, title):
    #Need to have a specs row for each row in the subplot and each row has to define each column
    collist = []
    x = 1
    while x <= cols:
        collist.append({'type': 'pie'})
        x += 1
    speclist =[]
    x = 1
    while x<= rows:
        speclist.append(collist)
        x +=1

    subfig = make_subplots(rows=rows, cols=cols, specs=speclist)
    tempcol = 1
    temprow = 1
    for project,data in jsondata.items():
        if data:
            fig = goPie(project, data)
            subfig.add_trace(fig,row = temprow, col = tempcol)  
            if tempcol == cols:
                tempcol = 1
                temprow = temprow + 1
            else:
                tempcol = tempcol + 1
        subfig.update_layout(height= height, title_text=title)
    return subfig

# %%
def getProjects(testmode):
    if testmode:
        #projectlist = ["TCGA-UCS", "TCGA-OV", "TCGA-GBM","TCGA-KICH", "TCGA-KIRC", "TCGA-BRCA"]
        projectlist = ["TCGA-BRCA"]
    else:
        projectlist = unique_terms("ResearchSubject.associated_project")
        #projectquery = """SELECT DISTINCT(_project) FROM gdc-bq-sample.cda_mvp.v3, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File) AS _File, UNNEST(_File.associated_project) as _project"""
        #resultsid = runNewAPIQuery(projectquery, None)
        #projresults = getResults(resultsid,0,100)
        #projectlist = []
        #for projresult in projresults['result']:
        #    projectlist.append(projresult['_project'])
    return projectlist

# %%
def runAPIQuery(querystring, limit):
    #Using a limit:
    if limit is not None:
        cdaURL = "https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3?limit={}".format(str(limit))
    else:
        cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3'
    headers = {'accept' : 'application/json', 'Content-Type' : 'text/plain'}

    request = requests.post(cdaURL, headers = headers, data = querystring)

    if request.status_code == 200:
        return request.json()
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code,query))

# %%
def runNewAPIQuery(querystring,limit):
    #Due to a change in the API, queries now return a query ID, not the result.
    if limit is not None:
        cdaURL = "https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3?limit={}".format(str(limit))
    else:
        #cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query/v3'
        cdaURL = 'https://cda.cda-dev.broadinstitute.org/api/v1/sql-query'
    headers = {'accept' : 'application/json', 'Content-Type' : 'text/plain'}

    request = requests.post(cdaURL, headers = headers, data = querystring)

    if request.status_code == 200:
        result = request.json()
        query_id = result['query_id']
        return query_id
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code))

# %%
def runLibQuery(querystring):
    results = Q.sql(querystring)
    return results

# %%
def getResults(queryid, offset, limit):
    #curl -X GET "https://cda.cda-dev.broadinstitute.org/api/v1/query/bcff531e-0ada-4d43-9d81-ae9ab05efacb?offset=10&limit=100" -H "accept: application/json"
    resultURL = "https://cda.cda-dev.broadinstitute.org/api/v1/query/{}?offset={}&limit={}".format(queryid, str(offset), str(limit))
    #pprint.pprint(resultURL)
    headers = {'accept' : 'application/json'}
    
    request = requests.get(resultURL, headers = headers)
    
    if request.status_code == 200:
        #pprint.pprint(request.json())
        return request.json()
    else:
        raise Exception ("Query failed code {}. {}".format(request.status_code))

# %%
def samplePerDataCategory(project):
    querystring = """SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3, 
        UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File) 
        AS _File, UNNEST(_File.associated_project) as _project WHERE _project= '{}' GROUP BY _File.data_category""".format(project)
    return querystring

# %%
def parseSamplePerDataCategory(results):
    finaldata = {}
    #finaldata['next_url'] = str(results['next_url'])
    for result in results['result']:
        finaldata[result['data_category']] = result['spec_count']
    return finaldata

# %%
def parseLibSamplePerDataCategory(results):
    finaldata = {}
    for result in results:
        finaldata[result['data_category']] = result['spec_count']
        #pprint.pprint(result)
    return finaldata

# %% [markdown]
# <font color=blue> The section below uses the API directly</font>

# %%
#projectlist = getProjects(False)
projectlist = getProjects(True)
projectcount = len(projectlist)
countdata = {}
resultsets = {}
for project in projectlist:
    querystring = samplePerDataCategory(project)
    try:
        apiresults = runNewAPIQuery(querystring, None)
        resultsets[project] = apiresults
    except Exception as e:
        pprint.pprint(e)
pprint.pprint("Completed")
# Out:
# 'Completed'

# %% [markdown]
# <font color=blue>This section functions the same as the previous, but uses the cdapython Q.sql function instead to run the query</font>

# %%
projectlist = getProjects(False)
projectcount = len(projectlist)
countdata = {}
for project in projectlist:
    querystring = samplePerDataCategory(project)
    libresults = runLibQuery(querystring)
    countdata[project] = parseLibSamplePerDataCategory(libresults)
pprint.pprint("Completed")
# Out:
# QueryID: 642c21ed-6cce-4094-9ab1-74816fdd9f75
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-MSK' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 69184d01-dfac-425f-a1e7-863ec3d56655
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-DFCI' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: 1654d0a7-b40d-48b0-89ec-a4563344c497
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'FM-AD' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: 17047633-c95b-44d0-822f-e42cf0c14bc5
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-LGG' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 2f443562-85da-4ddb-bc89-7615d9bc2072
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-JHU' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: ffbc0a3a-0c3c-4b35-b62f-5ba8acf489f1
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-ALL-P2' GROUP BY _File.data_category
# Offset: 0
# Count: 5
# Total Row Count: 5
# More pages: False
#
#
# QueryID: 321d71c7-527b-4923-9b57-940f3f43cb4f
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-NKI' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: 89777a48-2770-4dcc-acf9-d2566e6272f1
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-SKCM' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: a13a5da0-4d05-45bc-af75-09bb831e74d7
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-SARC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 78b6dfde-5029-4bd2-a487-949a177eed49
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC3-Discovery' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: e77b3e90-e250-46b9-94bc-a275809cf75c
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-HNSC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 3ac58d6e-3f8f-4a02-bdbb-694812acacb7
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Integrated Proteogenomic Characterization of HBV-related Hepatocellular carcinoma' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 5f1425ca-7a70-44b8-a1cb-220d8236cc9c
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-ESCA' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: c0fc9137-469b-4c14-927d-98429847a42c
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-THCA' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 0262d66c-c3c1-4f8e-b9f6-54d2637cca2b
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-UCEC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 9170b4a3-5952-4ada-9d16-42fdffa8e844
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-COAD' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 3bad41af-9a04-4f2a-b3a4-9b4b77cfd362
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-BRCA' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: dcb1f3fb-507e-4cc9-8483-9b3fef48d713
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-NBL' GROUP BY _File.data_category
# Offset: 0
# Count: 4
# Total Row Count: 4
# More pages: False
#
#
# QueryID: 3bc985b1-2fa0-4c60-82c8-31b6be7566e7
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TRIO-CRU' GROUP BY _File.data_category
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False
#
#
# QueryID: 93ca1d3d-b2a5-4950-82c9-9dac114843c8
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-CESC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 1d68dec1-cd2d-47a5-bfa3-07cdce257873
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'VAREPOP-APOLLO' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: a6f72318-ee15-4cb6-adee-0bd1253c8832
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CGCI-HTMCP-CC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: b06cadf5-5b75-4356-9b2c-910ddaa9482b
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-LIHC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: e3222304-e520-4583-84f2-27d6e8d533e2
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'OHSU-CNL' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: 505a27c4-6b71-48df-8e45-e5b7b6fc01e5
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'ORGANOID-PANCREATIC' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: b874a2b4-925a-4d62-aaa2-737793fc2b3f
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Human Early-Onset Gastric Cancer - Korea University' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: d1aeebe7-7dcc-459c-a5da-40ea74085692
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC3-Other' GROUP BY _File.data_category
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False
#
#
# QueryID: e83fcc8b-237e-4cfa-afb9-4313aa94c83b
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'NCICCR-DLBCL' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: c36f948a-2f57-4365-ac6b-40341fa5f1a2
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-UCS' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 5d632997-0d08-4714-9493-e4816bef1ace
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-ALL-P3' GROUP BY _File.data_category
# Offset: 0
# Count: 4
# Total Row Count: 4
# More pages: False
#
#
# QueryID: 1ccc2793-0703-44be-8d06-907f115a5f85
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'REBC-THYR' GROUP BY _File.data_category
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False
#
#
# QueryID: 393922d9-18db-4d82-b31a-400044549910
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-READ' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 6e8c2f0b-6951-4129-849b-7af1bd0ec51d
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-MESO' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: af31f29b-1181-4997-83d3-bc12abc23e4d
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-STAD' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 5c05c755-9632-4601-a915-4efa46e44e88
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-ACC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: d525ef6d-d1e6-4e1d-b72a-11be38f6dd35
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-THYM' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 616ca79e-ef20-4d17-ae27-ea482cad3c5c
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CMI-MPC' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: 6bffbc4d-d5de-4117-b706-f66e6ea3eeac
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CMI-ASC' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 39797ea3-4a9e-4bf0-b219-78007d2ff1e1
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'PJ25730263' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: a43f8061-b955-4717-a769-8f17db9596d5
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-ALL-P1' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 3bd35287-1f10-48c9-a32c-8f71d7706474
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-MDA' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: 76b10fb5-4196-4821-b405-2e271cccc401
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-GBM' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 00815e2c-de5f-46e1-8714-a64822aca4c8
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-AML' GROUP BY _File.data_category
# Offset: 0
# Count: 5
# Total Row Count: 5
# More pages: False
#
#
# QueryID: faad60ff-73e8-4be0-acef-51536e8586e1
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-UVM' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 126af6c8-912d-49f3-83db-7b04e3f868f1
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Academia Sinica LUAD-100' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: dd6e2c35-9488-4b64-93bc-cde9b2837f91
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC-3' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 0b7b74a2-1e88-445a-98d0-3c74600e3488
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-LUSC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 13f2046e-0f1f-4057-b16d-481908741695
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-VICC' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 09df28f5-f04a-4b4b-84c8-b29f3f833ac3
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-GRCC' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: 32f2b1c3-f2a1-499e-a55c-0647fe3e3e53
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC-2' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: a61d0ad1-e737-4f75-bec7-37239969beb6
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-KIRP' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 16fcc4c5-57b4-417c-8fa3-6efd0b9c7bbd
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-LUAD' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 6055d6eb-25f3-4903-9ec9-3aeca41db16a
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-KIRC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 98643227-adcf-43ba-bb9a-7e6c2b65c828
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-WT' GROUP BY _File.data_category
# Offset: 0
# Count: 5
# Total Row Count: 5
# More pages: False
#
#
# QueryID: 64848d71-a5a9-4e15-8883-ca9178b9c49b
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-OS' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 20f830fb-811e-44e1-9936-821e7ca3bc99
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-OV' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 8f7fb101-aa7a-443e-8f7c-f7039539b7d2
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'GENIE-UHN' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: e200f13f-0519-4599-92c0-d17fe1762876
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC-TCGA' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 5e051c7f-8446-4fed-bd81-5f425738d7a9
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'MMRF-COMMPASS' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: e0aa7522-e2ee-45fe-8114-2dbf1d1495f0
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'BEATAML1.0-COHORT' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: e35ceb71-c71a-4b56-93ff-c3881ba6e38d
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CGCI-BLGSP' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: badc28f6-1dbe-4018-81db-c5ca61bdfb54
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Proteogenomic Analysis of Pediatric Brain Cancer Tumors Pilot Study' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 09ead48f-a0ab-4e43-91fa-943806e1e5b3
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'HCMI-CMDC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 3b1bdcf6-30ed-4dd4-9350-a096defc87af
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-PCPG' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 97de32f3-3426-48fe-8601-a8c79ba22923
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-TGCT' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 78db3fcd-944d-42bf-865b-c413799dff46
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'BEATAML1.0-CRENOLANIB' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: c4899c4b-66d0-4d74-8e18-7bf9f9502d86
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CMI-MBC' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: b3433d42-4f15-48d2-afa8-c7c3ac069523
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-BLCA' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 4609bc12-637d-4101-a605-59419e3f5dc5
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-KICH' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 28475585-8475-4610-8b8a-f2f149bc52af
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-LAML' GROUP BY _File.data_category
# Offset: 0
# Count: 5
# Total Row Count: 5
# More pages: False
#
#
# QueryID: ae97e7df-166d-4bab-8cd6-75099c1dcedf
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-PRAD' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 731b990d-6774-4811-92e9-0d51239285ee
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-PAAD' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: a8c590a3-f4af-41cb-b435-b8bcd1f29f87
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-RT' GROUP BY _File.data_category
# Offset: 0
# Count: 3
# Total Row Count: 3
# More pages: False
#
#
# QueryID: 6fe3996a-531e-4c9d-85bd-8c0ec0696cd9
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-DLBC' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 7b1ae899-d203-4d63-9ce9-5d710e9d86cb
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TCGA-CHOL' GROUP BY _File.data_category
# Offset: 0
# Count: 6
# Total Row Count: 6
# More pages: False
#
#
# QueryID: 5ddb66a0-5e9a-4e16-aa42-f04abb72eeee
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'WCDT-MCRPC' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: 510fde31-018c-4b36-9586-87897d6c171c
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Oral Squamous Cell Carcinoma - Chang Gung University' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: 783cbc83-2941-4c55-b622-6002e6b1dfb2
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC2-Other' GROUP BY _File.data_category
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False
#
#
# QueryID: ea6ddcdf-dc32-4a14-a705-a4e729c2e27f
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CTSP-DLBCL1' GROUP BY _File.data_category
# Offset: 0
# Count: 2
# Total Row Count: 2
# More pages: False
#
#
# QueryID: 38b63376-378d-4146-a0fc-0c0edd37eb9a
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Georgetown Lung Cancer Proteomics Study' GROUP BY _File.data_category
# Offset: 0
# Count: 1
# Total Row Count: 1
# More pages: False
#
#
# QueryID: 28a03f74-99f4-4f24-8790-083c9e71f968
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'TARGET-CCSK' GROUP BY _File.data_category
# Offset: 0
# Count: 5
# Total Row Count: 5
# More pages: False
#
#
# QueryID: e452b1bf-d304-494e-9926-d23fdfc0c8c3
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'Proteogenomic Translational Research Centers (PTRC)' GROUP BY _File.data_category
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False
#
#
# QueryID: 013da3db-9b77-464a-af65-2ebc10ac421a
# Query: SELECT COUNT(DISTINCT _Specimen.id) AS spec_count, _FILE.data_category FROM gdc-bq-sample.cda_mvp.v3,
#         UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Specimen) AS _Specimen, UNNEST(_Specimen.File)
#         AS _File, UNNEST(_File.associated_project) as _project WHERE _project= 'CPTAC2 Retrospective' GROUP BY _File.data_category
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False
#
# 'Completed'

# %% [markdown]
# <font color=blue> The section below requires direct API results.  It queries for the resultsID and then parses that.  Will not work with results from Q</font>

# %%
for disease, resultid in resultsets.items():
    try:
        results = getResults(resultid,0,10)
        parsedresults = parseSamplePerDataCategory(results)
        #pprint.pprint(parsedresults)
        countdata[disease] = parsedresults
    except Exception as e:
        pprint.pprint(e)
pprint.pprint("Completed")
# Out:
# 'Completed'

# %%
cols = 3
rows = math.ceil(projectcount/cols)
height =300*rows
title = 'Samples in Data Category'
plotlySubplots(countdata, cols, rows, height,title)
