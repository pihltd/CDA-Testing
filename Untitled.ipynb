# %%
from cdapython import unique_terms
import pprint

# %%
unique_terms("ResearchSubject.associated_project")
# Out:
# ['GENIE-DFCI',
#  'FM-AD',
#  'GENIE-MSK',
#  'GENIE-JHU',
#  'TARGET-ALL-P2',
#  'TCGA-HNSC',
#  'GENIE-NKI',
#  'CPTAC3-Discovery',
#  'TCGA-ESCA',
#  'TCGA-THCA',
#  'TCGA-UCEC',
#  'TCGA-COAD',
#  'TARGET-NBL',
#  'REBC-THYR',
#  'TCGA-BRCA',
#  'TCGA-LGG',
#  'TCGA-SARC',
#  'NCICCR-DLBCL',
#  'ORGANOID-PANCREATIC',
#  'Integrated Proteogenomic Characterization of HBV-related Hepatocellular carcinoma',
#  'Human Early-Onset Gastric Cancer - Korea University',
#  'TCGA-MESO',
#  'TCGA-LIHC',
#  'TCGA-STAD',
#  'PJ25730263',
#  'OHSU-CNL',
#  'TRIO-CRU',
#  'TCGA-CESC',
#  'TCGA-THYM',
#  'TARGET-ALL-P3',
#  'TCGA-READ',
#  'TCGA-SKCM',
#  'TCGA-ACC',
#  'CMI-ASC',
#  'CMI-MPC',
#  'CGCI-HTMCP-CC',
#  'TCGA-UCS',
#  'CPTAC3-Other',
#  'TARGET-ALL-P1',
#  'VAREPOP-APOLLO',
#  'GENIE-MDA',
#  'GENIE-UHN',
#  'TARGET-AML',
#  'BEATAML1.0-CRENOLANIB',
#  'BEATAML1.0-COHORT',
#  'GENIE-VICC',
#  'MMRF-COMMPASS',
#  'GENIE-GRCC',
#  'CPTAC-2',
#  'CPTAC-3',
#  'TCGA-PRAD',
# ...

# %%
unique_terms("File.associated_project")
# Out:
# ['FM-AD',
#  'GENIE-DFCI',
#  'CPTAC3-Discovery',
#  'cptac_lscc',
#  'GENIE-MSK',
#  'GENIE-JHU',
#  'GENIE-NKI',
#  'TCGA-LIHC',
#  'TCGA-BRCA',
#  'TCGA-SKCM',
#  'TARGET-NBL',
#  'TARGET-ALL-P2',
#  'cptac_gbm',
#  'TCGA-LGG',
#  'tcga_gbm',
#  'CGCI-HTMCP-CC',
#  'TCGA-ESCA',
#  'TCGA-STAD',
#  'TCGA-THCA',
#  'TCGA-UCEC',
#  'TCGA-COAD',
#  'OHSU-CNL',
#  'TCGA-CESC',
#  'TCGA-HNSC',
#  'TCGA-READ',
#  'TCGA-ACC',
#  'TCGA-SARC',
#  'TCGA-MESO',
#  'tcga_cesc',
#  'REBC-THYR',
#  'tcga_ucec',
#  'tcga_lgg',
#  'NCICCR-DLBCL',
#  'cptac_luad',
#  'TRIO-CRU',
#  'TCGA-THYM',
#  'CMI-ASC',
#  'prostate_mri_us_biopsy',
#  'lidc_idri',
#  'rider_lung_pet_ct',
#  'breast_cancer_screening_dbt',
#  'victre',
#  'nsclc_radiomics',
#  'cptac_sar',
#  'hnscc',
#  'head_neck_pet_ct',
#  'breast_diagnosis',
#  'ispy1',
#  'prostatex',
#  'qin_brain_dsc_mri',
#  'rembrandt',
#  'acrin_nsclc_fdg_pet',
#  'prostate_fused_mri_pathology',
#  'head_neck_cetuximab',
#  'lctsc',
#  '4d_lung',
# ...
