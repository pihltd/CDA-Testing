# %%
from cdapython import Q, unique_terms, columns, query

# %% [markdown]
# <font color=blue>Test Query 1 Find data from all Subjects who have been treated with “Radiation Therapy, NOS” and have both genomic and proteomic data.</font>

# %% [markdown]
# <font color=green> check to see that ResearchSubject.Diagnosis.Treatment.treatment_type is the right place to search</font>

# %%
unique_terms("ResearchSubject.Diagnosis.Treatment.treatment_type")
# Out:
# ['Radiation Therapy, NOS',
#  'Chemotherapy',
#  'Surgery',
#  'Targeted Molecular Therapy',
#  'Brachytherapy, Low Dose',
#  'Radiation, External Beam',
#  'Stem Cell Transplantation, Allogeneic',
#  'Brachytherapy, High Dose',
#  'Hormone Therapy',
#  'Stereotactic Radiosurgery',
#  'Radiation, Stereotactic/Gamma Knife/SRS',
#  'Ablation, Radiofrequency',
#  'Radiation, 2D Conventional',
#  'Pharmaceutical Therapy, NOS',
#  'Immunotherapy (Including Vaccines)',
#  None,
#  'Stem Cell Transplantation, Autologous',
#  'Radiation, 3D Conformal',
#  'Radiation, Proton Beam',
#  'Radiation, Intensity-Modulated Radiotherapy']

# %%
treatment = Q('ResearchSubject.Diagnosis.Treatment.treatment_type = "Radiation Therapy, NOS"')
r = treatment.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 9770 ms
#
# QueryID: e745486e-41ba-4ff1-8389-1c8d6418e7a0
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment WHERE (_Treatment.treatment_type = 'Radiation Therapy, NOS')
# Offset: 0
# Count: 100
# Total Row Count: 11792
# More pages: True

# %% [markdown]
# <font color=green> So far, so good, 11792 cases</font>

# %% [markdown]
# <font color=green>The ability to select GDC or PDC exists in multiple places but since we're looking for data, ResearchSubject.File.identifier.system seems appropriate</font>

# %%
gdc = Q('ResearchSubject.File.identifier.system = "GDC"')
pdc = Q('ResearchSubject.File.identifier.system = "PDC"')

# %% [markdown]
# <font color=green> Guessing that a FROM query is needed

# %%
q = treatment.From(gdc.And(pdc))
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 992 ms
#
# QueryID: 3e510407-2d2a-4299-a850-09222269c56b
# Query: SELECT all_v2.* FROM (SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.File) AS _File, UNNEST(_File.identifier) AS _identifier WHERE ((_identifier.system = 'GDC') AND (_identifier.system = 'PDC'))) AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment WHERE (_Treatment.treatment_type = 'Radiation Therapy, NOS')
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False

# %% [markdown]
# <font color=green> Well THAT didn't work.  Maybe an AND?</font>

# %%
q = treatment.And(gdc.And(pdc))
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 884 ms
#
# QueryID: 44f20a56-4e17-42e7-af17-66ec661a3020
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment, UNNEST(_ResearchSubject.File) AS _File, UNNEST(_File.identifier) AS _identifier WHERE ((_Treatment.treatment_type = 'Radiation Therapy, NOS') AND ((_identifier.system = 'GDC') AND (_identifier.system = 'PDC')))
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False

# %% [markdown]
# <font color=green> Huh.  Time for a breakdown</font>

# %%
q_gdc = treatment.And(gdc)
r_gdc = q_gdc.run()
print(r_gdc)
# Out:
# Getting results from database
# ERROR:root:
#             Http Status: 500
#             Error Message: Response too large to return. Consider specifying a destination table in your job configuration. For more details, see https://cloud.google.com/bigquery/troubleshooting-errors
# Total execution time: 22089 ms
# None

# %%
q_pdc = treatment.And(pdc)
r_pdc = q_pdc.run()
print(r_pdc)
# Out:
# Getting results from database
#
# Total execution time: 728 ms
#
# QueryID: bb44f965-95ca-46b6-81b3-c8859b99aef8
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment, UNNEST(_ResearchSubject.File) AS _File, UNNEST(_File.identifier) AS _identifier WHERE ((_Treatment.treatment_type = 'Radiation Therapy, NOS') AND (_identifier.system = 'PDC'))
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False

# %% [markdown]
# <font color = green> Is File the wrong hierarchy?  Maybe use ResearchSubject instead?</font>

# %%
gdc_rs = Q('ResearchSubject.identifier.system = "GDC"')
pdc_rs = Q('ResearchSubject.identifier.system = "PDC"')

# %%
q_pdc = treatment.And(pdc_rs)
r = q_pdc.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 794 ms
#
# QueryID: 385a8517-d341-4bf3-89c1-2ee3c53fff9a
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment, UNNEST(_ResearchSubject.identifier) AS _identifier WHERE ((_Treatment.treatment_type = 'Radiation Therapy, NOS') AND (_identifier.system = 'PDC'))
# Offset: 0
# Count: 0
# Total Row Count: 0
# More pages: False

# %% [markdown]
# <font color=green> So this is a fundamental problem, there are 0 cases in PDC having received the treatment (or PDC doesn't support treatment.</font>

# %%
q = treatment.And(gdc_rs)
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 28354 ms
#
# QueryID: 7882a0f6-7e5b-4b8b-9dfe-051f2ec4cbc2
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment, UNNEST(_ResearchSubject.identifier) AS _identifier WHERE ((_Treatment.treatment_type = 'Radiation Therapy, NOS') AND (_identifier.system = 'GDC'))
# Offset: 0
# Count: 100
# Total Row Count: 11792
# More pages: True

# %% [markdown]
# <font color = green> So the starting set needs to be cases from GDC that have had the treatment.</font>

# %%
q = pdc_rs.From(treatment.And(gdc_rs))
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 29215 ms
#
# QueryID: c39ad931-a06a-4389-a799-114c5c6ad98f
# Query: SELECT all_v2.* FROM (SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis, UNNEST(_Diagnosis.Treatment) AS _Treatment, UNNEST(_ResearchSubject.identifier) AS _identifier WHERE ((_Treatment.treatment_type = 'Radiation Therapy, NOS') AND (_identifier.system = 'GDC'))) AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.identifier) AS _identifier WHERE (_identifier.system = 'PDC')
# Offset: 0
# Count: 100
# Total Row Count: 369
# More pages: True

# %% [markdown]
# <font color = blue> Test 2 Find data from TCGA-BRCA project, with donors over the age of 50 with imaging data</font>

# %% [markdown]
# <font color=green> Step 1, find out how many cases over 50 in TCGA-BRCA</font>

# %%
project = Q('ResearchSubject.associated_project = "TCGA-BRCA"')
age = Q('ResearchSubject.Diagnosis.age_at_diagnosis > -50*365')

# %%
pr = project.run()
print(pr)
# Out:
# Getting results from database
#
# Total execution time: 23835 ms
#
# QueryID: e952665e-d37d-43f5-b30b-82099c28d0cb
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject WHERE (_ResearchSubject.associated_project = 'TCGA-BRCA')
# Offset: 0
# Count: 100
# Total Row Count: 1098
# More pages: True

# %%
ar = age.run()
print(ar)
# Out:
# Getting results from database
#
# Total execution time: 24905 ms
#
# QueryID: cb5d6468-deaf-4452-b14c-e480004eb50a
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis WHERE (_Diagnosis.age_at_diagnosis > -50*365)
# Offset: 0
# Count: 100
# Total Row Count: 40545
# More pages: True

# %%
q = project.And(age)
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 28314 ms
#
# QueryID: 011ca250-fe22-4207-a613-4fbfe6304f91
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis WHERE ((_ResearchSubject.associated_project = 'TCGA-BRCA') AND (_Diagnosis.age_at_diagnosis > -50*365))
# Offset: 0
# Count: 100
# Total Row Count: 1082
# More pages: True

# %% [markdown]
# <font color=green> So there ar 1082 cases over 50.  However, we know that IDC doesn't have ResearchSubjects, so need a different approach</font>

# %%
project = Q('ResearchSubject.associated_project = "TCGA-BRCA"')
age = Q('days_to_birth > -50*365')

# %%
pr = project.run()
print(pr)
# Out:
# Getting results from database
#
# Total execution time: 10547 ms
#
# QueryID: bf33d2f4-06b0-46a9-8927-76b67dc2944c
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject WHERE (_ResearchSubject.associated_project = 'TCGA-BRCA')
# Offset: 0
# Count: 100
# Total Row Count: 1098
# More pages: True

# %%
ar = age.run()
print(ar)
# Out:
# Getting results from database
#
# Total execution time: 9205 ms
#
# QueryID: 0cf1f5f9-bce1-4c94-ad27-eb9b9dd2778b
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2 WHERE (all_v2.days_to_birth > -50*365)
# Offset: 0
# Count: 100
# Total Row Count: 12682
# More pages: True

# %%
idc = Q('identifier.system = "IDC"')
ir = idc.run()
print(ir)
# Out:
# Getting results from database
#
# Total execution time: 14399 ms
#
# QueryID: 2ba4dbae-a002-4eeb-a56d-2f6c699530f9
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(identifier) AS _identifier WHERE (_identifier.system = 'IDC')
# Offset: 0
# Count: 100
# Total Row Count: 43428
# More pages: True

# %%
q = project.And(age)
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 19482 ms
#
# QueryID: 660db860-082c-4f0d-9a98-2810373c706a
# Query: SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject WHERE ((_ResearchSubject.associated_project = 'TCGA-BRCA') AND (all_v2.days_to_birth > -50*365))
# Offset: 0
# Count: 100
# Total Row Count: 288
# More pages: True

# %%
q = idc.From(project.And(age))
r = q.run()
print(r)
# Out:
# Getting results from database
#
# Total execution time: 14074 ms
#
# QueryID: 367e05e8-83d5-47aa-b44f-d90cb438d0d8
# Query: SELECT all_v2.* FROM (SELECT all_v2.* FROM gdc-bq-sample.integration.all_v2 AS all_v2, UNNEST(ResearchSubject) AS _ResearchSubject WHERE ((_ResearchSubject.associated_project = 'TCGA-BRCA') AND (all_v2.days_to_birth > -50*365))) AS all_v2, UNNEST(identifier) AS _identifier WHERE (_identifier.system = 'IDC')
# Offset: 0
# Count: 51
# Total Row Count: 51
# More pages: False

# %%
r.pretty_print(0)
# Out:
# {'File': [{'associated_project': 'TCGA-BRCA',
#            'byte_size': '21968',
#            'checksum': '9f8a71d0bd68b3d6f51da92919ef9c73',
#            'data_category': 'Proteome Profiling',
#            'data_type': 'Protein Expression Quantification',
#            'drs_uri': 'drs://dg.4DFC:c840cf2d-36d4-4e0a-8053-4d8897cfa9cf',
#            'file_format': 'TSV',
#            'id': 'c840cf2d-36d4-4e0a-8053-4d8897cfa9cf',
#            'identifier': [{'system': 'GDC',
#                            'value': 'c840cf2d-36d4-4e0a-8053-4d8897cfa9cf'}],
#            'label': 'TCGA-E2-A1B5-01A-31-A13E-20_RPPA_data.tsv'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '175093',
#            'checksum': '5f22ab47a7aa08352f38d1f275053f61',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Raw Simple Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:438d76d9-9248-4923-b6c4-276d8997093b',
#            'file_format': 'VCF',
#            'id': '438d76d9-9248-4923-b6c4-276d8997093b',
#            'identifier': [{'system': 'GDC',
#                            'value': '438d76d9-9248-4923-b6c4-276d8997093b'}],
#            'label': '438d76d9-9248-4923-b6c4-276d8997093b.vcf'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '358732',
#            'checksum': '1700cc8fa282635235473bac179ef2c5',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:22656b71-476a-4b5f-9f3b-82afb29a34bc',
#            'file_format': 'BCR Biotab',
#            'id': '22656b71-476a-4b5f-9f3b-82afb29a34bc',
#            'identifier': [{'system': 'GDC',
#                            'value': '22656b71-476a-4b5f-9f3b-82afb29a34bc'}],
#            'label': 'nationwidechildrens.org_biospecimen_portion_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '961048',
#            'checksum': 'a83b5130bd671998aa1ec339a542121d',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:1e6b79ff-9787-4cbe-b19d-ebabb6b43589',
#            'file_format': 'BCR Biotab',
#            'id': '1e6b79ff-9787-4cbe-b19d-ebabb6b43589',
#            'identifier': [{'system': 'GDC',
#                            'value': '1e6b79ff-9787-4cbe-b19d-ebabb6b43589'}],
#            'label': 'nationwidechildrens.org_clinical_drug_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '3469',
#            'checksum': '9147133a51e20b86b6baac8c5cb1c6ac',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Masked Copy Number Segment',
#            'drs_uri': 'drs://dg.4DFC:66a3d9f9-793b-41a2-bfb6-6ad48809863a',
#            'file_format': 'TXT',
#            'id': '66a3d9f9-793b-41a2-bfb6-6ad48809863a',
#            'identifier': [{'system': 'GDC',
#                            'value': '66a3d9f9-793b-41a2-bfb6-6ad48809863a'}],
#            'label': 'JOUAL_p_TCGA_b96_SNP_N_GenomeWideSNP_6_G06_748042.nocnv_grch38.seg.v2.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '3482242',
#            'checksum': 'c00d78127516d11953ae043a671364b5',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Gene Level Copy Number',
#            'drs_uri': 'drs://dg.4DFC:00a310cf-5740-4413-bc8e-d4ada63d6d48',
#            'file_format': 'TXT',
#            'id': '00a310cf-5740-4413-bc8e-d4ada63d6d48',
#            'identifier': [{'system': 'GDC',
#                            'value': '00a310cf-5740-4413-bc8e-d4ada63d6d48'}],
#            'label': 'TCGA-BRCA.4fd5a826-8410-4572-9403-960947308df7.gene_level_copy_number.tsv'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '24161125',
#            'checksum': '23f303806e40f6f30fc52b5a9c6eb327',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Masked Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:6c93f518-1956-4435-9806-37185266d248',
#            'file_format': 'MAF',
#            'id': '6c93f518-1956-4435-9806-37185266d248',
#            'identifier': [{'system': 'GDC',
#                            'value': '6c93f518-1956-4435-9806-37185266d248'}],
#            'label': 'TCGA.BRCA.varscan.6c93f518-1956-4435-9806-37185266d248.DR-10.0.somatic.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '118858',
#            'checksum': '4dce72daab60c6b11c5973b421ea35f0',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:edbb5de2-d0b5-4a07-a0e1-19e952a5117d',
#            'file_format': 'BCR Biotab',
#            'id': 'edbb5de2-d0b5-4a07-a0e1-19e952a5117d',
#            'identifier': [{'system': 'GDC',
#                            'value': 'edbb5de2-d0b5-4a07-a0e1-19e952a5117d'}],
#            'label': 'nationwidechildrens.org_biospecimen_diagnostic_slides_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '47061',
#            'checksum': '0ac1c35b77b9278e95086c124808c759',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:a9baecf0-5549-4396-8805-a6d1681d11cd',
#            'file_format': 'BCR Biotab',
#            'id': 'a9baecf0-5549-4396-8805-a6d1681d11cd',
#            'identifier': [{'system': 'GDC',
#                            'value': 'a9baecf0-5549-4396-8805-a6d1681d11cd'}],
#            'label': 'nationwidechildrens.org_clinical_follow_up_v4.0_nte_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '21432702885',
#            'checksum': 'c4efdb80071c07c44153aa7ee2252a44',
#            'data_category': 'Sequencing Reads',
#            'data_type': 'Aligned Reads',
#            'drs_uri': 'drs://dg.4DFC:04b12d6d-a141-492a-9ede-66106beec09f',
#            'file_format': 'BAM',
#            'id': '04b12d6d-a141-492a-9ede-66106beec09f',
#            'identifier': [{'system': 'GDC',
#                            'value': '04b12d6d-a141-492a-9ede-66106beec09f'}],
#            'label': 'TCGA-E2-A1B5-01A-21D-A12Q-09_IlluminaGA-DNASeq_exome_gdc_realn.bam'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '117592',
#            'checksum': '0b465b3f0b9bddf2416ccd74994805a4',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:22f38342-3f1a-47e5-9025-c19719fa21d0',
#            'file_format': 'BCR Biotab',
#            'id': '22f38342-3f1a-47e5-9025-c19719fa21d0',
#            'identifier': [{'system': 'GDC',
#                            'value': '22f38342-3f1a-47e5-9025-c19719fa21d0'}],
#            'label': 'nationwidechildrens.org_clinical_follow_up_v1.5_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '18979',
#            'checksum': '98b54db831c530bf1f7ec6fc2d32a367',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:6fd0e269-7225-4bfd-9e4e-3cc1644d96e0',
#            'file_format': 'BCR SSF XML',
#            'id': '6fd0e269-7225-4bfd-9e4e-3cc1644d96e0',
#            'identifier': [{'system': 'GDC',
#                            'value': '6fd0e269-7225-4bfd-9e4e-3cc1644d96e0'}],
#            'label': 'nationwidechildrens.org_ssf.TCGA-E2-A1B5.xml'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '217642',
#            'checksum': 'f5b49c0103a9f1dc12555f4eb0c8dfaa',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:5907be67-69f6-4339-8264-952a2462bea5',
#            'file_format': 'BCR Biotab',
#            'id': '5907be67-69f6-4339-8264-952a2462bea5',
#            'identifier': [{'system': 'GDC',
#                            'value': '5907be67-69f6-4339-8264-952a2462bea5'}],
#            'label': 'nationwidechildrens.org_ssf_normal_controls_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '1728468',
#            'checksum': '103577529e4355cfd0a5da055ea5a403',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:d0c967b5-78ee-4bc4-9493-3cbe44af1bf5',
#            'file_format': 'BCR Biotab',
#            'id': 'd0c967b5-78ee-4bc4-9493-3cbe44af1bf5',
#            'identifier': [{'system': 'GDC',
#                            'value': 'd0c967b5-78ee-4bc4-9493-3cbe44af1bf5'}],
#            'label': 'nationwidechildrens.org_biospecimen_analyte_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '1700943',
#            'checksum': 'f271f56d44b62d41bd6ddb0d26e525b4',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:8162d394-8b64-4da2-9f5b-d164c54b9608',
#            'file_format': 'BCR Biotab',
#            'id': '8162d394-8b64-4da2-9f5b-d164c54b9608',
#            'identifier': [{'system': 'GDC',
#                            'value': '8162d394-8b64-4da2-9f5b-d164c54b9608'}],
#            'label': 'nationwidechildrens.org_clinical_patient_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '2561498',
#            'checksum': '518662abcb430af9704a29d32e596c4b',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:950ee56c-df20-4b39-867e-c73f17d0f4f6',
#            'file_format': 'BCR Biotab',
#            'id': '950ee56c-df20-4b39-867e-c73f17d0f4f6',
#            'identifier': [{'system': 'GDC',
#                            'value': '950ee56c-df20-4b39-867e-c73f17d0f4f6'}],
#            'label': 'nationwidechildrens.org_biospecimen_aliquot_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '123240',
#            'checksum': '002ad34525a69b2603c7947c53260b82',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:62d4515f-a30b-4b1a-b2dd-c8bf9476e803',
#            'file_format': 'BCR Biotab',
#            'id': '62d4515f-a30b-4b1a-b2dd-c8bf9476e803',
#            'identifier': [{'system': 'GDC',
#                            'value': '62d4515f-a30b-4b1a-b2dd-c8bf9476e803'}],
#            'label': 'nationwidechildrens.org_clinical_follow_up_v4.0_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '353327',
#            'checksum': 'f694515fd191ab8d3c0b073e6f2fc7cb',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:41fd4c6c-2932-4c6b-914f-7abaea9dc8a0',
#            'file_format': 'BCR Biotab',
#            'id': '41fd4c6c-2932-4c6b-914f-7abaea9dc8a0',
#            'identifier': [{'system': 'GDC',
#                            'value': '41fd4c6c-2932-4c6b-914f-7abaea9dc8a0'}],
#            'label': 'nationwidechildrens.org_ssf_tumor_samples_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '31058116',
#            'checksum': '4a00a1c3611c2ddcb2eed684c451eea7',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Masked Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:995c0111-d90b-4140-bee7-3845436c3b42',
#            'file_format': 'MAF',
#            'id': '995c0111-d90b-4140-bee7-3845436c3b42',
#            'identifier': [{'system': 'GDC',
#                            'value': '995c0111-d90b-4140-bee7-3845436c3b42'}],
#            'label': 'TCGA.BRCA.mutect.995c0111-d90b-4140-bee7-3845436c3b42.DR-10.0.somatic.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '253859',
#            'checksum': '6dc51d56ef86bcabce55ae3a06015a55',
#            'data_category': 'Transcriptome Profiling',
#            'data_type': 'Gene Expression Quantification',
#            'drs_uri': 'drs://dg.4DFC:88140784-8c64-452a-92e2-53dffef3db82',
#            'file_format': 'TXT',
#            'id': '88140784-8c64-452a-92e2-53dffef3db82',
#            'identifier': [{'system': 'GDC',
#                            'value': '88140784-8c64-452a-92e2-53dffef3db82'}],
#            'label': 'd4924657-2b67-4083-8190-bd4c15534066.htseq.counts.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '61183816504',
#            'checksum': 'b7eb8b2888c9c09110c92f1b7ed513db',
#            'data_category': 'Sequencing Reads',
#            'data_type': 'Aligned Reads',
#            'drs_uri': 'drs://dg.4DFC:64307494-c3c6-4d74-bf4b-938f7706909e',
#            'file_format': 'BAM',
#            'id': '64307494-c3c6-4d74-bf4b-938f7706909e',
#            'identifier': [{'system': 'GDC',
#                            'value': '64307494-c3c6-4d74-bf4b-938f7706909e'}],
#            'label': 'TCGA-E2-A1B5-11A-23D-A12Q-09_IlluminaGA-DNASeq_exome_gdc_realn.bam'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '2007410',
#            'checksum': 'a7c56789917d1f7e2e1191af0c40db3f',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Annotated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:e9e7904c-c3ab-42af-9613-5919133d49e1',
#            'file_format': 'VCF',
#            'id': 'e9e7904c-c3ab-42af-9613-5919133d49e1',
#            'identifier': [{'system': 'GDC',
#                            'value': 'e9e7904c-c3ab-42af-9613-5919133d49e1'}],
#            'label': 'e9e7904c-c3ab-42af-9613-5919133d49e1.vep.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '10901',
#            'checksum': 'd403adbb38c6b910c800802d3a0c7e36',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Allele-specific Copy Number Segment',
#            'drs_uri': 'drs://dg.4DFC:4d6ccd06-5a86-4d1d-ab7b-8e628e0a014f',
#            'file_format': 'TXT',
#            'id': '4d6ccd06-5a86-4d1d-ab7b-8e628e0a014f',
#            'identifier': [{'system': 'GDC',
#                            'value': '4d6ccd06-5a86-4d1d-ab7b-8e628e0a014f'}],
#            'label': 'TCGA-BRCA.4fd5a826-8410-4572-9403-960947308df7.ascat2.allelic_specific.seg.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '342644',
#            'checksum': '3b1a01de91ff035ea611959562d0b572',
#            'data_category': 'Transcriptome Profiling',
#            'data_type': 'Isoform Expression Quantification',
#            'drs_uri': 'drs://dg.4DFC:acd05696-1ab3-4e43-8520-2a141acb9e25',
#            'file_format': 'TXT',
#            'id': 'acd05696-1ab3-4e43-8520-2a141acb9e25',
#            'identifier': [{'system': 'GDC',
#                            'value': 'acd05696-1ab3-4e43-8520-2a141acb9e25'}],
#            'label': 'daf3b479-79cc-4f4e-b136-923ef6156e48.mirbase21.isoforms.quantification.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '417578',
#            'checksum': '039253c77a6125842558ba2a20ec5187',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:c10090b8-fa42-4e32-86a0-9dedceb5b605',
#            'file_format': 'BCR Biotab',
#            'id': 'c10090b8-fa42-4e32-86a0-9dedceb5b605',
#            'identifier': [{'system': 'GDC',
#                            'value': 'c10090b8-fa42-4e32-86a0-9dedceb5b605'}],
#            'label': 'nationwidechildrens.org_biospecimen_slide_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '16910889',
#            'checksum': '21d64325c5780be0b1fadcc55fe5e3d4',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Masked Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:7dd592e3-5950-4438-96d5-3c718aca3f13',
#            'file_format': 'MAF',
#            'id': '7dd592e3-5950-4438-96d5-3c718aca3f13',
#            'identifier': [{'system': 'GDC',
#                            'value': '7dd592e3-5950-4438-96d5-3c718aca3f13'}],
#            'label': 'TCGA.BRCA.somaticsniper.7dd592e3-5950-4438-96d5-3c718aca3f13.DR-10.0.somatic.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '621054920',
#            'checksum': 'a5d844676518cfe8517d86cccf588ccc',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Aggregated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:f9ff49e9-31ce-4051-9157-4bf4b0c5859a',
#            'file_format': 'MAF',
#            'id': 'f9ff49e9-31ce-4051-9157-4bf4b0c5859a',
#            'identifier': [{'system': 'GDC',
#                            'value': 'f9ff49e9-31ce-4051-9157-4bf4b0c5859a'}],
#            'label': 'TCGA.BRCA.somaticsniper.f9ff49e9-31ce-4051-9157-4bf4b0c5859a.DR-10.0.protected.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '299623',
#            'checksum': '7eacf215ba6fc8392c1757879dbdbf29',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Raw Simple Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:143beda1-a873-402f-b806-53789a41b13f',
#            'file_format': 'VCF',
#            'id': '143beda1-a873-402f-b806-53789a41b13f',
#            'identifier': [{'system': 'GDC',
#                            'value': '143beda1-a873-402f-b806-53789a41b13f'}],
#            'label': '143beda1-a873-402f-b806-53789a41b13f.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '188640',
#            'checksum': '748761c13bd36ee33fa8805b5047cc6b',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Raw Simple Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:20fe2917-1117-4cd4-a138-0202e7c86c3e',
#            'file_format': 'VCF',
#            'id': '20fe2917-1117-4cd4-a138-0202e7c86c3e',
#            'identifier': [{'system': 'GDC',
#                            'value': '20fe2917-1117-4cd4-a138-0202e7c86c3e'}],
#            'label': '20fe2917-1117-4cd4-a138-0202e7c86c3e.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '1882061658',
#            'checksum': 'ae12bbce7abcc03eff228935fa8d3d22',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Aggregated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:053f01ed-3154-4aea-9e7f-932c435034b3',
#            'file_format': 'MAF',
#            'id': '053f01ed-3154-4aea-9e7f-932c435034b3',
#            'identifier': [{'system': 'GDC',
#                            'value': '053f01ed-3154-4aea-9e7f-932c435034b3'}],
#            'label': 'TCGA.BRCA.mutect.053f01ed-3154-4aea-9e7f-932c435034b3.DR-10.0.protected.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '56089',
#            'checksum': '1e77a077d0a88946942912ba8d6be477',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Raw Simple Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:a1b5b6e0-faec-4f92-a0c5-55084e0889cb',
#            'file_format': 'VCF',
#            'id': 'a1b5b6e0-faec-4f92-a0c5-55084e0889cb',
#            'identifier': [{'system': 'GDC',
#                            'value': 'a1b5b6e0-faec-4f92-a0c5-55084e0889cb'}],
#            'label': 'a1b5b6e0-faec-4f92-a0c5-55084e0889cb.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '400774',
#            'checksum': '9cca54164b8159e4b25bf6cfff4c7a90',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Annotated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:a4eee36d-4df5-447c-af25-6ad8ee7828d2',
#            'file_format': 'VCF',
#            'id': 'a4eee36d-4df5-447c-af25-6ad8ee7828d2',
#            'identifier': [{'system': 'GDC',
#                            'value': 'a4eee36d-4df5-447c-af25-6ad8ee7828d2'}],
#            'label': 'a4eee36d-4df5-447c-af25-6ad8ee7828d2.vep.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '50204',
#            'checksum': 'a8b7b92ca1c8193da9cb5d99b460fcb9',
#            'data_category': 'Transcriptome Profiling',
#            'data_type': 'miRNA Expression Quantification',
#            'drs_uri': 'drs://dg.4DFC:347a8e69-dab4-4920-a395-8ee80256d0ff',
#            'file_format': 'TXT',
#            'id': '347a8e69-dab4-4920-a395-8ee80256d0ff',
#            'identifier': [{'system': 'GDC',
#                            'value': '347a8e69-dab4-4920-a395-8ee80256d0ff'}],
#            'label': 'daf3b479-79cc-4f4e-b136-923ef6156e48.mirbase21.mirnas.quantification.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '517592',
#            'checksum': 'efb70f561245181f4e656b4de224f485',
#            'data_category': 'Transcriptome Profiling',
#            'data_type': 'Gene Expression Quantification',
#            'drs_uri': 'drs://dg.4DFC:f1c50289-1db1-4066-a44c-34e89963ee6d',
#            'file_format': 'TXT',
#            'id': 'f1c50289-1db1-4066-a44c-34e89963ee6d',
#            'identifier': [{'system': 'GDC',
#                            'value': 'f1c50289-1db1-4066-a44c-34e89963ee6d'}],
#            'label': 'd4924657-2b67-4083-8190-bd4c15534066.FPKM.txt.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '69088',
#            'checksum': '4ab1b571056283419be174ab1e1f875a',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:a88c168e-4bba-4bd2-9c0c-77934444cc1c',
#            'file_format': 'BCR Biotab',
#            'id': 'a88c168e-4bba-4bd2-9c0c-77934444cc1c',
#            'identifier': [{'system': 'GDC',
#                            'value': 'a88c168e-4bba-4bd2-9c0c-77934444cc1c'}],
#            'label': 'nationwidechildrens.org_clinical_nte_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '141289017',
#            'checksum': 'f97bec0507dc3368de13cea281f55959',
#            'data_category': 'DNA Methylation',
#            'data_type': 'Methylation Beta Value',
#            'drs_uri': 'drs://dg.4DFC:08a69940-871f-487c-9f64-1ca4b610c030',
#            'file_format': 'TXT',
#            'id': '08a69940-871f-487c-9f64-1ca4b610c030',
#            'identifier': [{'system': 'GDC',
#                            'value': '08a69940-871f-487c-9f64-1ca4b610c030'}],
#            'label': 'jhu-usc.edu_BRCA.HumanMethylation450.8.lvl-3.TCGA-E2-A1B5-11A-23D-A12R-05.gdc_hg38.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '23970',
#            'checksum': '8926489c8114ef9b2880598ac450c67e',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Copy Number Segment',
#            'drs_uri': 'drs://dg.4DFC:fb8cd86a-37fd-4547-88c6-59dcb2660e56',
#            'file_format': 'TXT',
#            'id': 'fb8cd86a-37fd-4547-88c6-59dcb2660e56',
#            'identifier': [{'system': 'GDC',
#                            'value': 'fb8cd86a-37fd-4547-88c6-59dcb2660e56'}],
#            'label': 'JOUAL_p_TCGA_b96_SNP_N_GenomeWideSNP_6_G06_748042.grch38.seg.v2.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '39381',
#            'checksum': '4f6606f6b12f952e0339a40396cd7c92',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:f434b393-9e32-4ca2-aa1a-3b0de36b5ffe',
#            'file_format': 'BCR Biotab',
#            'id': 'f434b393-9e32-4ca2-aa1a-3b0de36b5ffe',
#            'identifier': [{'system': 'GDC',
#                            'value': 'f434b393-9e32-4ca2-aa1a-3b0de36b5ffe'}],
#            'label': 'nationwidechildrens.org_clinical_omf_v4.0_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '7284385084',
#            'checksum': '62e26d76eaf15593d5a46d3ea969fe6c',
#            'data_category': 'Sequencing Reads',
#            'data_type': 'Aligned Reads',
#            'drs_uri': 'drs://dg.4DFC:601278ff-a240-4e4b-a7e0-2d1e7c8ad3c9',
#            'file_format': 'BAM',
#            'id': '601278ff-a240-4e4b-a7e0-2d1e7c8ad3c9',
#            'identifier': [{'system': 'GDC',
#                            'value': '601278ff-a240-4e4b-a7e0-2d1e7c8ad3c9'}],
#            'label': '9432ae7d-e8f9-45d7-90ca-a07edac39c03_gdc_realn_rehead.bam'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '255213',
#            'checksum': 'f956383c2a66f83a0c224217bd3a0ad5',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Annotated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:ef6c5a79-37c5-4a0e-a143-1f32051b085c',
#            'file_format': 'VCF',
#            'id': 'ef6c5a79-37c5-4a0e-a143-1f32051b085c',
#            'identifier': [{'system': 'GDC',
#                            'value': 'ef6c5a79-37c5-4a0e-a143-1f32051b085c'}],
#            'label': 'ef6c5a79-37c5-4a0e-a143-1f32051b085c.vep.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '789503',
#            'checksum': '8528185ddd57118e0109dd50d1f48303',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:a24d7574-e419-47ce-9293-b9b29f854a10',
#            'file_format': 'BCR Biotab',
#            'id': 'a24d7574-e419-47ce-9293-b9b29f854a10',
#            'identifier': [{'system': 'GDC',
#                            'value': 'a24d7574-e419-47ce-9293-b9b29f854a10'}],
#            'label': 'nationwidechildrens.org_biospecimen_protocol_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '154614',
#            'checksum': '2a79ad158a204d1af81108b178280bea',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:43569ab9-5a32-45ef-a07e-e93f45416a16',
#            'file_format': 'BCR Biotab',
#            'id': '43569ab9-5a32-45ef-a07e-e93f45416a16',
#            'identifier': [{'system': 'GDC',
#                            'value': '43569ab9-5a32-45ef-a07e-e93f45416a16'}],
#            'label': 'nationwidechildrens.org_biospecimen_shipment_portion_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '154883',
#            'checksum': '13885c9a052e6874e14158139982bb60',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:0a40467f-9495-4c5b-b56e-3347a3ee0572',
#            'file_format': 'BCR Biotab',
#            'id': '0a40467f-9495-4c5b-b56e-3347a3ee0572',
#            'identifier': [{'system': 'GDC',
#                            'value': '0a40467f-9495-4c5b-b56e-3347a3ee0572'}],
#            'label': 'nationwidechildrens.org_clinical_radiation_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '1005255',
#            'checksum': '0fa678866ff3f85a842d821463c8c5d6',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:c5039e7e-14d8-4e59-ba20-0d3fa38b86df',
#            'file_format': 'BCR Biotab',
#            'id': 'c5039e7e-14d8-4e59-ba20-0d3fa38b86df',
#            'identifier': [{'system': 'GDC',
#                            'value': 'c5039e7e-14d8-4e59-ba20-0d3fa38b86df'}],
#            'label': 'nationwidechildrens.org_biospecimen_sample_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '148613852',
#            'checksum': '12ac15df6973cfab8a7fef182082972a',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Aggregated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:cd0d1636-ae95-4141-94b3-8218eb3b8b25',
#            'file_format': 'MAF',
#            'id': 'cd0d1636-ae95-4141-94b3-8218eb3b8b25',
#            'identifier': [{'system': 'GDC',
#                            'value': 'cd0d1636-ae95-4141-94b3-8218eb3b8b25'}],
#            'label': 'TCGA.BRCA.muse.cd0d1636-ae95-4141-94b3-8218eb3b8b25.DR-10.0.protected.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '14936',
#            'checksum': '0530f3c164d92a06e0d1d0e45c9af922',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Masked Copy Number Segment',
#            'drs_uri': 'drs://dg.4DFC:13a1d329-722d-428d-a8a9-557fc7e9735d',
#            'file_format': 'TXT',
#            'id': '13a1d329-722d-428d-a8a9-557fc7e9735d',
#            'identifier': [{'system': 'GDC',
#                            'value': '13a1d329-722d-428d-a8a9-557fc7e9735d'}],
#            'label': 'JOUAL_p_TCGA_b96_SNP_N_GenomeWideSNP_6_E05_748038.nocnv_grch38.seg.v2.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '141269303',
#            'checksum': 'd2a0262e2b62355c7ab3642dc4a97397',
#            'data_category': 'DNA Methylation',
#            'data_type': 'Methylation Beta Value',
#            'drs_uri': 'drs://dg.4DFC:bca95404-88e7-4699-a4c9-cfda16554e09',
#            'file_format': 'TXT',
#            'id': 'bca95404-88e7-4699-a4c9-cfda16554e09',
#            'identifier': [{'system': 'GDC',
#                            'value': 'bca95404-88e7-4699-a4c9-cfda16554e09'}],
#            'label': 'jhu-usc.edu_BRCA.HumanMethylation450.8.lvl-3.TCGA-E2-A1B5-01A-21D-A12R-05.gdc_hg38.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '23039649',
#            'checksum': 'f814c909403da10f3d2200d2a4b45f42',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Masked Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:b8ca5856-9819-459c-87c5-94e91aca4032',
#            'file_format': 'MAF',
#            'id': 'b8ca5856-9819-459c-87c5-94e91aca4032',
#            'identifier': [{'system': 'GDC',
#                            'value': 'b8ca5856-9819-459c-87c5-94e91aca4032'}],
#            'label': 'TCGA.BRCA.muse.b8ca5856-9819-459c-87c5-94e91aca4032.DR-10.0.somatic.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '40624',
#            'checksum': 'a300135fe2d07d8f044b60ae07b9f1c3',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Copy Number Segment',
#            'drs_uri': 'drs://dg.4DFC:1cc745e8-be3b-4bf3-b226-e7dfc853d41f',
#            'file_format': 'TXT',
#            'id': '1cc745e8-be3b-4bf3-b226-e7dfc853d41f',
#            'identifier': [{'system': 'GDC',
#                            'value': '1cc745e8-be3b-4bf3-b226-e7dfc853d41f'}],
#            'label': 'JOUAL_p_TCGA_b96_SNP_N_GenomeWideSNP_6_E05_748038.grch38.seg.v2.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '132798',
#            'checksum': '3f272c3e22a864a30cae75e5155bdd46',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Annotated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:d7fdebd7-4703-4f02-b380-1619d26ee4e7',
#            'file_format': 'VCF',
#            'id': 'd7fdebd7-4703-4f02-b380-1619d26ee4e7',
#            'identifier': [{'system': 'GDC',
#                            'value': 'd7fdebd7-4703-4f02-b380-1619d26ee4e7'}],
#            'label': 'd7fdebd7-4703-4f02-b380-1619d26ee4e7.vep.vcf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '74487',
#            'checksum': '26b53d22fcff602ef52088eef3b48cd9',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:15bb59e5-6f0f-48f2-8ec3-e72863c9a928',
#            'file_format': 'BCR XML',
#            'id': '15bb59e5-6f0f-48f2-8ec3-e72863c9a928',
#            'identifier': [{'system': 'GDC',
#                            'value': '15bb59e5-6f0f-48f2-8ec3-e72863c9a928'}],
#            'label': 'nationwidechildrens.org_clinical.TCGA-E2-A1B5.xml'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '519219',
#            'checksum': '3f652686d0c2d6aec9fd281d8c6332ce',
#            'data_category': 'Transcriptome Profiling',
#            'data_type': 'Gene Expression Quantification',
#            'drs_uri': 'drs://dg.4DFC:9fa4616a-b31c-4513-9acd-2903118bfd1e',
#            'file_format': 'TXT',
#            'id': '9fa4616a-b31c-4513-9acd-2903118bfd1e',
#            'identifier': [{'system': 'GDC',
#                            'value': '9fa4616a-b31c-4513-9acd-2903118bfd1e'}],
#            'label': 'd4924657-2b67-4083-8190-bd4c15534066.FPKM-UQ.txt.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '88218',
#            'checksum': '3661d7e37453744290f719389b65e1d3',
#            'data_category': 'Biospecimen',
#            'data_type': 'Biospecimen Supplement',
#            'drs_uri': 'drs://dg.4DFC:8ea68253-1408-4c62-852e-4d25bcf7d102',
#            'file_format': 'BCR XML',
#            'id': '8ea68253-1408-4c62-852e-4d25bcf7d102',
#            'identifier': [{'system': 'GDC',
#                            'value': '8ea68253-1408-4c62-852e-4d25bcf7d102'}],
#            'label': 'nationwidechildrens.org_biospecimen.TCGA-E2-A1B5.xml'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '372177',
#            'checksum': '29f6255a8ddac7f43b3a2a30fe3e2b64',
#            'data_category': 'Clinical',
#            'data_type': 'Clinical Supplement',
#            'drs_uri': 'drs://dg.4DFC:403b5cef-8173-47c7-b56a-cc94dcfbb2e3',
#            'file_format': 'BCR Biotab',
#            'id': '403b5cef-8173-47c7-b56a-cc94dcfbb2e3',
#            'identifier': [{'system': 'GDC',
#                            'value': '403b5cef-8173-47c7-b56a-cc94dcfbb2e3'}],
#            'label': 'nationwidechildrens.org_clinical_follow_up_v2.1_brca.txt'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '342281557',
#            'checksum': '735d3ccbf64778336ef535388e2c0939',
#            'data_category': 'Simple Nucleotide Variation',
#            'data_type': 'Aggregated Somatic Mutation',
#            'drs_uri': 'drs://dg.4DFC:5a6c3396-8c49-4c25-8a86-7ae63a887c43',
#            'file_format': 'MAF',
#            'id': '5a6c3396-8c49-4c25-8a86-7ae63a887c43',
#            'identifier': [{'system': 'GDC',
#                            'value': '5a6c3396-8c49-4c25-8a86-7ae63a887c43'}],
#            'label': 'TCGA.BRCA.varscan.5a6c3396-8c49-4c25-8a86-7ae63a887c43.DR-10.0.protected.maf.gz'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '76335083',
#            'checksum': '39f98ea02d91e501229cd88ea1845f50',
#            'data_category': 'Sequencing Reads',
#            'data_type': 'Aligned Reads',
#            'drs_uri': 'drs://dg.4DFC:60cc4ac4-6062-4c77-96a8-075129bed32e',
#            'file_format': 'BAM',
#            'id': '60cc4ac4-6062-4c77-96a8-075129bed32e',
#            'identifier': [{'system': 'GDC',
#                            'value': '60cc4ac4-6062-4c77-96a8-075129bed32e'}],
#            'label': 'TCGA-E2-A1B5-01A-21R-A12O-13_mirna_gdc_realn.bam'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '20382636605',
#            'checksum': '9a70189f2114c7bb58c449c57bb9ec17',
#            'data_category': 'Sequencing Reads',
#            'data_type': 'Aligned Reads',
#            'drs_uri': 'drs://dg.4DFC:a583d8b9-f90d-4e3f-b43c-0a482102b037',
#            'file_format': 'BAM',
#            'id': 'a583d8b9-f90d-4e3f-b43c-0a482102b037',
#            'identifier': [{'system': 'GDC',
#                            'value': 'a583d8b9-f90d-4e3f-b43c-0a482102b037'}],
#            'label': 'TCGA-E2-A1B5-10A-01D-A12Q-09_IlluminaGA-DNASeq_exome_gdc_realn.bam'},
#           {'associated_project': 'TCGA-BRCA',
#            'byte_size': '45161979',
#            'checksum': 'cd4bc677968e6b8eea7b663dba692c40',
#            'data_category': 'Copy Number Variation',
#            'data_type': 'Gene Level Copy Number Scores',
#            'drs_uri': 'drs://dg.4DFC:9afe6c9d-ed2f-402a-b043-77f042c4e7fc',
#            'file_format': 'TXT',
#            'id': '9afe6c9d-ed2f-402a-b043-77f042c4e7fc',
#            'identifier': [{'system': 'GDC',
#                            'value': '9afe6c9d-ed2f-402a-b043-77f042c4e7fc'}],
#            'label': 'BRCA.focal_score_by_genes.txt'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/0d063860-b8c5-4140-a2d5-f8adb9058850.dcm',
#            'file_format': 'DICOM',
#            'id': '0d063860-b8c5-4140-a2d5-f8adb9058850',
#            'identifier': [{'system': 'IDC',
#                            'value': '0d063860-b8c5-4140-a2d5-f8adb9058850'}],
#            'label': '0d063860-b8c5-4140-a2d5-f8adb9058850.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/dd90d493-cc65-4c56-aaa0-5a85470c85ef.dcm',
#            'file_format': 'DICOM',
#            'id': 'dd90d493-cc65-4c56-aaa0-5a85470c85ef',
#            'identifier': [{'system': 'IDC',
#                            'value': 'dd90d493-cc65-4c56-aaa0-5a85470c85ef'}],
#            'label': 'dd90d493-cc65-4c56-aaa0-5a85470c85ef.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/65fb6153-c9d9-4aef-b9fd-7103183e16b4.dcm',
#            'file_format': 'DICOM',
#            'id': '65fb6153-c9d9-4aef-b9fd-7103183e16b4',
#            'identifier': [{'system': 'IDC',
#                            'value': '65fb6153-c9d9-4aef-b9fd-7103183e16b4'}],
#            'label': '65fb6153-c9d9-4aef-b9fd-7103183e16b4.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/2a8b0c0d-9e6b-45c1-a8f7-64f9796b3f55.dcm',
#            'file_format': 'DICOM',
#            'id': '2a8b0c0d-9e6b-45c1-a8f7-64f9796b3f55',
#            'identifier': [{'system': 'IDC',
#                            'value': '2a8b0c0d-9e6b-45c1-a8f7-64f9796b3f55'}],
#            'label': '2a8b0c0d-9e6b-45c1-a8f7-64f9796b3f55.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/19bb236e-c251-476a-8b38-da46c10ae9a2.dcm',
#            'file_format': 'DICOM',
#            'id': '19bb236e-c251-476a-8b38-da46c10ae9a2',
#            'identifier': [{'system': 'IDC',
#                            'value': '19bb236e-c251-476a-8b38-da46c10ae9a2'}],
#            'label': '19bb236e-c251-476a-8b38-da46c10ae9a2.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/371280a3-d204-4471-a079-bfb2fa682571.dcm',
#            'file_format': 'DICOM',
#            'id': '371280a3-d204-4471-a079-bfb2fa682571',
#            'identifier': [{'system': 'IDC',
#                            'value': '371280a3-d204-4471-a079-bfb2fa682571'}],
#            'label': '371280a3-d204-4471-a079-bfb2fa682571.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/e4d70079-57a7-4f9f-9e96-e79a3a9554a6.dcm',
#            'file_format': 'DICOM',
#            'id': 'e4d70079-57a7-4f9f-9e96-e79a3a9554a6',
#            'identifier': [{'system': 'IDC',
#                            'value': 'e4d70079-57a7-4f9f-9e96-e79a3a9554a6'}],
#            'label': 'e4d70079-57a7-4f9f-9e96-e79a3a9554a6.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/cd82e18c-e9f1-42fe-a19d-848b25d8c2d5.dcm',
#            'file_format': 'DICOM',
#            'id': 'cd82e18c-e9f1-42fe-a19d-848b25d8c2d5',
#            'identifier': [{'system': 'IDC',
#                            'value': 'cd82e18c-e9f1-42fe-a19d-848b25d8c2d5'}],
#            'label': 'cd82e18c-e9f1-42fe-a19d-848b25d8c2d5.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/6f359698-ed96-4d09-8e21-a098da043d77.dcm',
#            'file_format': 'DICOM',
#            'id': '6f359698-ed96-4d09-8e21-a098da043d77',
#            'identifier': [{'system': 'IDC',
#                            'value': '6f359698-ed96-4d09-8e21-a098da043d77'}],
#            'label': '6f359698-ed96-4d09-8e21-a098da043d77.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/2536f437-ff20-4ee4-bd82-7c245bb0bd62.dcm',
#            'file_format': 'DICOM',
#            'id': '2536f437-ff20-4ee4-bd82-7c245bb0bd62',
#            'identifier': [{'system': 'IDC',
#                            'value': '2536f437-ff20-4ee4-bd82-7c245bb0bd62'}],
#            'label': '2536f437-ff20-4ee4-bd82-7c245bb0bd62.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/a05f183e-20bb-4a9c-b79c-2ac70701d2a2.dcm',
#            'file_format': 'DICOM',
#            'id': 'a05f183e-20bb-4a9c-b79c-2ac70701d2a2',
#            'identifier': [{'system': 'IDC',
#                            'value': 'a05f183e-20bb-4a9c-b79c-2ac70701d2a2'}],
#            'label': 'a05f183e-20bb-4a9c-b79c-2ac70701d2a2.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/ddc239f2-0760-4284-8c90-6650ae88b920.dcm',
#            'file_format': 'DICOM',
#            'id': 'ddc239f2-0760-4284-8c90-6650ae88b920',
#            'identifier': [{'system': 'IDC',
#                            'value': 'ddc239f2-0760-4284-8c90-6650ae88b920'}],
#            'label': 'ddc239f2-0760-4284-8c90-6650ae88b920.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/c42d0fd4-9555-45e3-9d2c-ce5a9cc82447.dcm',
#            'file_format': 'DICOM',
#            'id': 'c42d0fd4-9555-45e3-9d2c-ce5a9cc82447',
#            'identifier': [{'system': 'IDC',
#                            'value': 'c42d0fd4-9555-45e3-9d2c-ce5a9cc82447'}],
#            'label': 'c42d0fd4-9555-45e3-9d2c-ce5a9cc82447.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/6f9b9702-fe9d-43ef-b9dd-96d7612f1f1f.dcm',
#            'file_format': 'DICOM',
#            'id': '6f9b9702-fe9d-43ef-b9dd-96d7612f1f1f',
#            'identifier': [{'system': 'IDC',
#                            'value': '6f9b9702-fe9d-43ef-b9dd-96d7612f1f1f'}],
#            'label': '6f9b9702-fe9d-43ef-b9dd-96d7612f1f1f.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/65ed337d-346e-4ad0-af9f-a9f35ec1a4e2.dcm',
#            'file_format': 'DICOM',
#            'id': '65ed337d-346e-4ad0-af9f-a9f35ec1a4e2',
#            'identifier': [{'system': 'IDC',
#                            'value': '65ed337d-346e-4ad0-af9f-a9f35ec1a4e2'}],
#            'label': '65ed337d-346e-4ad0-af9f-a9f35ec1a4e2.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/ffec712b-4423-4b62-b087-9f718ef6ea34.dcm',
#            'file_format': 'DICOM',
#            'id': 'ffec712b-4423-4b62-b087-9f718ef6ea34',
#            'identifier': [{'system': 'IDC',
#                            'value': 'ffec712b-4423-4b62-b087-9f718ef6ea34'}],
#            'label': 'ffec712b-4423-4b62-b087-9f718ef6ea34.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/a95ab755-11c0-41ae-a975-2b94e3e6b052.dcm',
#            'file_format': 'DICOM',
#            'id': 'a95ab755-11c0-41ae-a975-2b94e3e6b052',
#            'identifier': [{'system': 'IDC',
#                            'value': 'a95ab755-11c0-41ae-a975-2b94e3e6b052'}],
#            'label': 'a95ab755-11c0-41ae-a975-2b94e3e6b052.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/aa7f6485-0da4-4da8-b688-98b0f291b3ce.dcm',
#            'file_format': 'DICOM',
#            'id': 'aa7f6485-0da4-4da8-b688-98b0f291b3ce',
#            'identifier': [{'system': 'IDC',
#                            'value': 'aa7f6485-0da4-4da8-b688-98b0f291b3ce'}],
#            'label': 'aa7f6485-0da4-4da8-b688-98b0f291b3ce.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/37664c9c-e2b1-40ce-a293-133091c5b94a.dcm',
#            'file_format': 'DICOM',
#            'id': '37664c9c-e2b1-40ce-a293-133091c5b94a',
#            'identifier': [{'system': 'IDC',
#                            'value': '37664c9c-e2b1-40ce-a293-133091c5b94a'}],
#            'label': '37664c9c-e2b1-40ce-a293-133091c5b94a.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/354eff79-b20b-4738-9cb7-560781ad061d.dcm',
#            'file_format': 'DICOM',
#            'id': '354eff79-b20b-4738-9cb7-560781ad061d',
#            'identifier': [{'system': 'IDC',
#                            'value': '354eff79-b20b-4738-9cb7-560781ad061d'}],
#            'label': '354eff79-b20b-4738-9cb7-560781ad061d.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/80ec1b63-8229-439b-8c68-b4901b338143.dcm',
#            'file_format': 'DICOM',
#            'id': '80ec1b63-8229-439b-8c68-b4901b338143',
#            'identifier': [{'system': 'IDC',
#                            'value': '80ec1b63-8229-439b-8c68-b4901b338143'}],
#            'label': '80ec1b63-8229-439b-8c68-b4901b338143.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/aca48ee2-fe2b-4022-aa9f-96942445ebf4.dcm',
#            'file_format': 'DICOM',
#            'id': 'aca48ee2-fe2b-4022-aa9f-96942445ebf4',
#            'identifier': [{'system': 'IDC',
#                            'value': 'aca48ee2-fe2b-4022-aa9f-96942445ebf4'}],
#            'label': 'aca48ee2-fe2b-4022-aa9f-96942445ebf4.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
#            'checksum': None,
#            'data_category': 'Imaging',
#            'data_type': 'MR',
#            'drs_uri': 'gs://idc-open/f94bbe69-4692-4188-8c37-7e41bf9b7c27.dcm',
#            'file_format': 'DICOM',
#            'id': 'f94bbe69-4692-4188-8c37-7e41bf9b7c27',
#            'identifier': [{'system': 'IDC',
#                            'value': 'f94bbe69-4692-4188-8c37-7e41bf9b7c27'}],
#            'label': 'f94bbe69-4692-4188-8c37-7e41bf9b7c27.dcm'},
#           {'associated_project': 'tcga_brca',
#            'byte_size': None,
# ...
#                                                     'value': '0e6a0f0c-7760-44c4-a558-a6905b5a9267'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'slide'},
#                                    {'File': [{'associated_project': 'TCGA-BRCA',
#                                               'byte_size': '141289017',
#                                               'checksum': 'f97bec0507dc3368de13cea281f55959',
#                                               'data_category': 'DNA '
#                                                                'Methylation',
#                                               'data_type': 'Methylation Beta '
#                                                            'Value',
#                                               'drs_uri': 'drs://dg.4DFC:08a69940-871f-487c-9f64-1ca4b610c030',
#                                               'file_format': 'TXT',
#                                               'id': '08a69940-871f-487c-9f64-1ca4b610c030',
#                                               'identifier': [{'system': 'GDC',
#                                                               'value': '08a69940-871f-487c-9f64-1ca4b610c030'}],
#                                               'label': 'jhu-usc.edu_BRCA.HumanMethylation450.8.lvl-3.TCGA-E2-A1B5-11A-23D-A12R-05.gdc_hg38.txt'},
#                                              {'associated_project': 'TCGA-BRCA',
#                                               'byte_size': '61183816504',
#                                               'checksum': 'b7eb8b2888c9c09110c92f1b7ed513db',
#                                               'data_category': 'Sequencing '
#                                                                'Reads',
#                                               'data_type': 'Aligned Reads',
#                                               'drs_uri': 'drs://dg.4DFC:64307494-c3c6-4d74-bf4b-938f7706909e',
#                                               'file_format': 'BAM',
#                                               'id': '64307494-c3c6-4d74-bf4b-938f7706909e',
#                                               'identifier': [{'system': 'GDC',
#                                                               'value': '64307494-c3c6-4d74-bf4b-938f7706909e'}],
#                                               'label': 'TCGA-E2-A1B5-11A-23D-A12Q-09_IlluminaGA-DNASeq_exome_gdc_realn.bam'}],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'c3543535-f96e-402f-b717-99e8b9a24b06',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': 'a1be1666-c76b-4470-9b99-ae4fb1071354',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': 'a1be1666-c76b-4470-9b99-ae4fb1071354'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'slide'},
#                                    {'File': [],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'c3543535-f96e-402f-b717-99e8b9a24b06',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': '883d9c05-5a91-4a7b-b024-637f1feb6134',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': '883d9c05-5a91-4a7b-b024-637f1feb6134'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'analyte'},
#                                    {'File': [],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': '883d9c05-5a91-4a7b-b024-637f1feb6134',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': 'ef350507-9f90-4658-8bd1-22f11f5ef0a1',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': 'ef350507-9f90-4658-8bd1-22f11f5ef0a1'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'aliquot'},
#                                    {'File': [{'associated_project': 'TCGA-BRCA',
#                                               'byte_size': '141289017',
#                                               'checksum': 'f97bec0507dc3368de13cea281f55959',
#                                               'data_category': 'DNA '
#                                                                'Methylation',
#                                               'data_type': 'Methylation Beta '
#                                                            'Value',
#                                               'drs_uri': 'drs://dg.4DFC:08a69940-871f-487c-9f64-1ca4b610c030',
#                                               'file_format': 'TXT',
#                                               'id': '08a69940-871f-487c-9f64-1ca4b610c030',
#                                               'identifier': [{'system': 'GDC',
#                                                               'value': '08a69940-871f-487c-9f64-1ca4b610c030'}],
#                                               'label': 'jhu-usc.edu_BRCA.HumanMethylation450.8.lvl-3.TCGA-E2-A1B5-11A-23D-A12R-05.gdc_hg38.txt'},
#                                              {'associated_project': 'TCGA-BRCA',
#                                               'byte_size': '61183816504',
#                                               'checksum': 'b7eb8b2888c9c09110c92f1b7ed513db',
#                                               'data_category': 'Sequencing '
#                                                                'Reads',
#                                               'data_type': 'Aligned Reads',
#                                               'drs_uri': 'drs://dg.4DFC:64307494-c3c6-4d74-bf4b-938f7706909e',
#                                               'file_format': 'BAM',
#                                               'id': '64307494-c3c6-4d74-bf4b-938f7706909e',
#                                               'identifier': [{'system': 'GDC',
#                                                               'value': '64307494-c3c6-4d74-bf4b-938f7706909e'}],
#                                               'label': 'TCGA-E2-A1B5-11A-23D-A12Q-09_IlluminaGA-DNASeq_exome_gdc_realn.bam'}],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'c3543535-f96e-402f-b717-99e8b9a24b06',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': 'a0de3e4b-d10f-44fc-ba41-b80a687029a1',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': 'a0de3e4b-d10f-44fc-ba41-b80a687029a1'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'analyte'},
#                                    {'File': [{'associated_project': 'TCGA-BRCA',
#                                               'byte_size': '61183816504',
#                                               'checksum': 'b7eb8b2888c9c09110c92f1b7ed513db',
#                                               'data_category': 'Sequencing '
#                                                                'Reads',
#                                               'data_type': 'Aligned Reads',
#                                               'drs_uri': 'drs://dg.4DFC:64307494-c3c6-4d74-bf4b-938f7706909e',
#                                               'file_format': 'BAM',
#                                               'id': '64307494-c3c6-4d74-bf4b-938f7706909e',
#                                               'identifier': [{'system': 'GDC',
#                                                               'value': '64307494-c3c6-4d74-bf4b-938f7706909e'}],
#                                               'label': 'TCGA-E2-A1B5-11A-23D-A12Q-09_IlluminaGA-DNASeq_exome_gdc_realn.bam'}],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'a0de3e4b-d10f-44fc-ba41-b80a687029a1',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': '86a6c2ed-a48a-4c8b-9af9-ef10d6fadf26',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': '86a6c2ed-a48a-4c8b-9af9-ef10d6fadf26'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'aliquot'},
#                                    {'File': [{'associated_project': 'TCGA-BRCA',
#                                               'byte_size': '141289017',
#                                               'checksum': 'f97bec0507dc3368de13cea281f55959',
#                                               'data_category': 'DNA '
#                                                                'Methylation',
#                                               'data_type': 'Methylation Beta '
#                                                            'Value',
#                                               'drs_uri': 'drs://dg.4DFC:08a69940-871f-487c-9f64-1ca4b610c030',
#                                               'file_format': 'TXT',
#                                               'id': '08a69940-871f-487c-9f64-1ca4b610c030',
#                                               'identifier': [{'system': 'GDC',
#                                                               'value': '08a69940-871f-487c-9f64-1ca4b610c030'}],
#                                               'label': 'jhu-usc.edu_BRCA.HumanMethylation450.8.lvl-3.TCGA-E2-A1B5-11A-23D-A12R-05.gdc_hg38.txt'}],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'a0de3e4b-d10f-44fc-ba41-b80a687029a1',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': '5a3c0585-4223-4081-b0ae-15d446576b0b',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': '5a3c0585-4223-4081-b0ae-15d446576b0b'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'aliquot'},
#                                    {'File': [],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'a0de3e4b-d10f-44fc-ba41-b80a687029a1',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': '622b2b20-d691-4041-833f-c940bf7eafc0',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': '622b2b20-d691-4041-833f-c940bf7eafc0'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'aliquot'},
#                                    {'File': [],
#                                     'age_at_collection': '-17039',
#                                     'anatomical_site': None,
#                                     'associated_project': 'TCGA-BRCA',
#                                     'derived_from_specimen': 'a0de3e4b-d10f-44fc-ba41-b80a687029a1',
#                                     'derived_from_subject': 'TCGA-E2-A1B5',
#                                     'id': '153321cb-e495-42f6-9c65-a64a33c068b2',
#                                     'identifier': [{'system': 'GDC',
#                                                     'value': '153321cb-e495-42f6-9c65-a64a33c068b2'}],
#                                     'primary_disease_type': 'Ductal and '
#                                                             'Lobular Neoplasms',
#                                     'source_material_type': 'Solid Tissue '
#                                                             'Normal',
#                                     'specimen_type': 'aliquot'}],
#                       'associated_project': 'TCGA-BRCA',
#                       'id': '7241b3d4-31ee-4fd2-a4a5-35a9d5f37d6a',
#                       'identifier': [{'system': 'GDC',
#                                       'value': '7241b3d4-31ee-4fd2-a4a5-35a9d5f37d6a'}],
#                       'primary_disease_site': 'Breast',
#                       'primary_disease_type': 'Ductal and Lobular Neoplasms'}],
#  'days_to_birth': '-17039',
#  'ethnicity': 'not hispanic or latino',
#  'id': 'TCGA-E2-A1B5',
#  'identifier': [{'system': 'GDC', 'value': 'TCGA-E2-A1B5'},
#                 {'system': 'IDC', 'value': 'TCGA-E2-A1B5'}],
#  'race': 'white',
#  'sex': 'female',
#  'subject_associated_project': ['TCGA-BRCA', 'tcga_brca']}

# %%
data_cat = {}
data_type = {}
for result in r:
    for file in result['File']:
        if file['data_type'] in data_type.keys():
            counter = data_type[file['data_type']]
            counter += 1
            data_type[file['data_type']] = counter
        else:
            data_type[file['data_type']] = 1
        if file['data_category'] in data_cat.keys():
            counter = data_cat[file['data_category']]
            counter += 1
            data_cat[file['data_category']] = counter
        else:
            data_cat[file['data_category']] = 1

# %%
print(data_cat)
# Out:
# {'Proteome Profiling': 45, 'Simple Nucleotide Variation': 784, 'Biospecimen': 612, 'Clinical': 512, 'Copy Number Variation': 377, 'Sequencing Reads': 245, 'Transcriptome Profiling': 333, 'DNA Methylation': 67, 'Imaging': 87608, 'Processed Mass Spectra': 361, 'Raw Mass Spectra': 366, 'Peptide Spectral Matches': 733}

# %%
print(data_type)
# Out:
# {'Protein Expression Quantification': 45, 'Raw Simple Somatic Mutation': 200, 'Biospecimen Supplement': 612, 'Clinical Supplement': 512, 'Masked Copy Number Segment': 110, 'Gene Level Copy Number': 53, 'Masked Somatic Mutation': 192, 'Aligned Reads': 245, 'Gene Expression Quantification': 201, 'Annotated Somatic Mutation': 200, 'Allele-specific Copy Number Segment': 53, 'Isoform Expression Quantification': 66, 'Aggregated Somatic Mutation': 192, 'miRNA Expression Quantification': 66, 'Methylation Beta Value': 67, 'Copy Number Segment': 110, 'Gene Level Copy Number Scores': 51, 'MR': 87549, 'SR': 59, 'Open Standard': 727, 'Proprietary': 366, 'Text': 367}
