# %%
from cdapython import Q

# %%
q1 = Q('ResearchSubject.Diagnosis.age_at_diagnosis > 50*365')

# %%
q2 = Q('ResearchSubject.associated_project = "TCGA-OV"')

# %%
q = q1.And(q2)

# %%
r = q.run()

# %%
print(r)
# Out:
# Query: SELECT * FROM gdc-bq-sample.cda_mvp.v2, UNNEST(ResearchSubject) AS _ResearchSubject, UNNEST(_ResearchSubject.Diagnosis) AS _Diagnosis WHERE ((_Diagnosis.age_at_diagnosis > 50*365) AND (_ResearchSubject.associated_project = 'TCGA-OV'))
# Offset: 0
# Limit: 1000
# Count: 461
# More pages: No

# %%
r.pretty_print(2)
# Out:
# { 'Diagnosis': [ { 'Treatment': [ { 'outcome': None,
#                                     'type': 'Radiation Therapy, NOS'},
#                                   { 'outcome': None,
#                                     'type': 'Pharmaceutical Therapy, NOS'}],
#                    'age_at_diagnosis': 20705,
#                    'id': '2ccc9ded-6131-5138-ac74-27f15e75a761',
#                    'morphology': '8441/3',
#                    'primary_diagnosis': 'Serous cystadenocarcinoma, NOS',
#                    'tumor_grade': 'not reported',
#                    'tumor_stage': 'not reported'}],
#   'ResearchSubject': [ { 'Diagnosis': [ { 'Treatment': [ { 'outcome': None,
#                                                            'type': 'Radiation '
#                                                                    'Therapy, '
#                                                                    'NOS'},
#                                                          { 'outcome': None,
#                                                            'type': 'Pharmaceutical '
#                                                                    'Therapy, '
#                                                                    'NOS'}],
#                                           'age_at_diagnosis': 20705,
#                                           'id': '2ccc9ded-6131-5138-ac74-27f15e75a761',
#                                           'morphology': '8441/3',
#                                           'primary_diagnosis': 'Serous '
#                                                                'cystadenocarcinoma, '
#                                                                'NOS',
#                                           'tumor_grade': 'not reported',
#                                           'tumor_stage': 'not reported'}],
#                          'Specimen': [ { 'File': [],
#                                          'age_at_collection': None,
#                                          'anatomical_site': None,
#                                          'associated_project': 'TCGA-OV',
#                                          'derived_from_specimen': 'Initial '
#                                                                   'sample',
#                                          'derived_from_subject': 'TCGA-09-0369',
#                                          'id': '8996acf9-a1e2-4356-a6c1-fd75d85d227c',
#                                          'identifier': [ { 'system': 'GDC',
#                                                            'value': '8996acf9-a1e2-4356-a6c1-fd75d85d227c'}],
#                                          'primary_disease_type': 'Cystic, '
#                                                                  'Mucinous and '
#                                                                  'Serous '
#                                                                  'Neoplasms',
#                                          'source_material_type': 'Blood '
#                                                                  'Derived '
#                                                                  'Normal',
#                                          'specimen_type': 'sample'},
#                                        { 'File': [],
#                                          'age_at_collection': None,
#                                          'anatomical_site': None,
#                                          'associated_project': 'TCGA-OV',
#                                          'derived_from_specimen': '8996acf9-a1e2-4356-a6c1-fd75d85d227c',
#                                          'derived_from_subject': 'TCGA-09-0369',
#                                          'id': '453a82bd-77b1-41c8-b346-086a78525a6e',
#                                          'identifier': [ { 'system': 'GDC',
#                                                            'value': '453a82bd-77b1-41c8-b346-086a78525a6e'}],
#                                          'primary_disease_type': 'Cystic, '
#                                                                  'Mucinous and '
#                                                                  'Serous '
#                                                                  'Neoplasms',
#                                          'source_material_type': 'Blood '
#                                                                  'Derived '
#                                                                  'Normal',
#                                          'specimen_type': 'portion'},
#                                        { 'File': [],
#                                          'age_at_collection': None,
#                                          'anatomical_site': None,
#                                          'associated_project': 'TCGA-OV',
#                                          'derived_from_specimen': '453a82bd-77b1-41c8-b346-086a78525a6e',
#                                          'derived_from_subject': 'TCGA-09-0369',
#                                          'id': 'cf317a8d-69a8-427f-944a-21a501d96416',
#                                          'identifier': [ { 'system': 'GDC',
#                                                            'value': 'cf317a8d-69a8-427f-944a-21a501d96416'}],
#                                          'primary_disease_type': 'Cystic, '
#                                                                  'Mucinous and '
#                                                                  'Serous '
#                                                                  'Neoplasms',
#                                          'source_material_type': 'Blood '
#                                                                  'Derived '
#                                                                  'Normal',
#                                          'specimen_type': 'analyte'},
#                                        { 'File': [],
#                                          'age_at_collection': None,
#                                          'anatomical_site': None,
#                                          'associated_project': 'TCGA-OV',
#                                          'derived_from_specimen': 'cf317a8d-69a8-427f-944a-21a501d96416',
#                                          'derived_from_subject': 'TCGA-09-0369',
#                                          'id': '06c329b0-275f-403c-acb5-3713f29f842a',
#                                          'identifier': [ { 'system': 'GDC',
#                                                            'value': '06c329b0-275f-403c-acb5-3713f29f842a'}],
#                                          'primary_disease_type': 'Cystic, '
#                                                                  'Mucinous and '
#                                                                  'Serous '
#                                                                  'Neoplasms',
#                                          'source_material_type': 'Blood '
#                                                                  'Derived '
#                                                                  'Normal',
#                                          'specimen_type': 'aliquot'},
#                                        { 'File': [ { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 3482368,
#                                                      'checksum': '25a9c93fd94d275bfd5dd2541066d0c6',
#                                                      'data_category': 'Copy '
#                                                                       'Number '
#                                                                       'Variation',
#                                                      'data_type': 'Gene Level '
#                                                                   'Copy Number',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-open/021f8b65-bf3a-4058-863d-23a9836a7f15/TCGA-OV.0ae9f973-4f93-48f0-a214-35d671d46fef.gene_level_copy_number.tsv',
#                                                      'id': '021f8b65-bf3a-4058-863d-23a9836a7f15',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '021f8b65-bf3a-4058-863d-23a9836a7f15'}],
#                                                      'label': 'TCGA-OV.0ae9f973-4f93-48f0-a214-35d671d46fef.gene_level_copy_number.tsv',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 179862,
#                                                      'checksum': '961671edd7684b40af59af26c131eb7a',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/03ce79a9-e98b-44f1-bb75-d92903cdd8bc/03ce79a9-e98b-44f1-bb75-d92903cdd8bc.vep.vcf.gz',
#                                                      'id': '03ce79a9-e98b-44f1-bb75-d92903cdd8bc',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '03ce79a9-e98b-44f1-bb75-d92903cdd8bc'}],
#                                                      'label': '03ce79a9-e98b-44f1-bb75-d92903cdd8bc.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 77651,
#                                                      'checksum': 'affeecf8d3740baa933f8ef6f2562c67',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/03e0e06f-aefe-4d77-896f-8f410f524924/03e0e06f-aefe-4d77-896f-8f410f524924.vcf.gz',
#                                                      'id': '03e0e06f-aefe-4d77-896f-8f410f524924',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '03e0e06f-aefe-4d77-896f-8f410f524924'}],
#                                                      'label': '03e0e06f-aefe-4d77-896f-8f410f524924.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 216647924,
#                                                      'checksum': '431606691f638bb07d9028e6605539c7',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Aggregated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/04da990e-67a3-4ead-ab08-448c7118624c/TCGA.OV.varscan.04da990e-67a3-4ead-ab08-448c7118624c.DR-10.0.protected.maf.gz',
#                                                      'id': '04da990e-67a3-4ead-ab08-448c7118624c',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '04da990e-67a3-4ead-ab08-448c7118624c'}],
#                                                      'label': 'TCGA.OV.varscan.04da990e-67a3-4ead-ab08-448c7118624c.DR-10.0.protected.maf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 3607,
#                                                      'checksum': 'ca5391d84e95ea5c90e6f50524305e21',
#                                                      'data_category': 'Copy '
#                                                                       'Number '
#                                                                       'Variation',
#                                                      'data_type': 'Masked Copy '
#                                                                   'Number '
#                                                                   'Segment',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-open/1002bb41-9775-4147-82cc-1d0dd43c7dac/COTES_p_TCGAaffxB8_9a_S_GenomeWideSNP_6_G07_293052.nocnv_grch38.seg.v2.txt',
#                                                      'id': '1002bb41-9775-4147-82cc-1d0dd43c7dac',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '1002bb41-9775-4147-82cc-1d0dd43c7dac'}],
#                                                      'label': 'COTES_p_TCGAaffxB8_9a_S_GenomeWideSNP_6_G07_293052.nocnv_grch38.seg.v2.txt',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 203949,
#                                                      'checksum': '2fdfe4570a49c7ca2583e44983554a7c',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/1300a3e3-4779-4d79-a91e-5acb3a58ba31/1300a3e3-4779-4d79-a91e-5acb3a58ba31.vep.vcf.gz',
#                                                      'id': '1300a3e3-4779-4d79-a91e-5acb3a58ba31',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '1300a3e3-4779-4d79-a91e-5acb3a58ba31'}],
#                                                      'label': '1300a3e3-4779-4d79-a91e-5acb3a58ba31.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 68003605,
#                                                      'checksum': 'e8efa1a9779a67b9e93e70a904ded8b6',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Aggregated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/1cb59aef-ef3f-4367-9a3d-f33f7fb93e40/TCGA.OV.muse.1cb59aef-ef3f-4367-9a3d-f33f7fb93e40.DR-10.0.protected.maf.gz',
#                                                      'id': '1cb59aef-ef3f-4367-9a3d-f33f7fb93e40',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '1cb59aef-ef3f-4367-9a3d-f33f7fb93e40'}],
#                                                      'label': 'TCGA.OV.muse.1cb59aef-ef3f-4367-9a3d-f33f7fb93e40.DR-10.0.protected.maf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 1015156,
#                                                      'checksum': '6a858f14b5806533b030076ea3ea76c3',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/2a4073d0-3eeb-44a3-9832-f9366dce5fb2/2a4073d0-3eeb-44a3-9832-f9366dce5fb2.vep.vcf.gz',
#                                                      'id': '2a4073d0-3eeb-44a3-9832-f9366dce5fb2',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '2a4073d0-3eeb-44a3-9832-f9366dce5fb2'}],
#                                                      'label': '2a4073d0-3eeb-44a3-9832-f9366dce5fb2.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 204001,
#                                                      'checksum': '256109e01ef741fbd927cde9f7748e7a',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/3312eae0-ff00-472f-b232-f3efc285dec3/3312eae0-ff00-472f-b232-f3efc285dec3.vep.vcf.gz',
#                                                      'id': '3312eae0-ff00-472f-b232-f3efc285dec3',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '3312eae0-ff00-472f-b232-f3efc285dec3'}],
#                                                      'label': '3312eae0-ff00-472f-b232-f3efc285dec3.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 902701,
#                                                      'checksum': 'e259353ebfca65733df50fbbc972cfd4',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/36f63e08-d66c-420a-adaf-65fa01befe8b/36f63e08-d66c-420a-adaf-65fa01befe8b.vep.vcf.gz',
#                                                      'id': '36f63e08-d66c-420a-adaf-65fa01befe8b',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '36f63e08-d66c-420a-adaf-65fa01befe8b'}],
#                                                      'label': '36f63e08-d66c-420a-adaf-65fa01befe8b.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 7593913,
#                                                      'checksum': '2e2acbce23e19909921e5f261e752ec6',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Masked '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-open/3e48014d-ce4a-4937-bba4-13eaf631a64a/TCGA.OV.somaticsniper.3e48014d-ce4a-4937-bba4-13eaf631a64a.DR-10.0.somatic.maf.gz',
#                                                      'id': '3e48014d-ce4a-4937-bba4-13eaf631a64a',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '3e48014d-ce4a-4937-bba4-13eaf631a64a'}],
#                                                      'label': 'TCGA.OV.somaticsniper.3e48014d-ce4a-4937-bba4-13eaf631a64a.DR-10.0.somatic.maf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 2396287,
#                                                      'checksum': 'deb95b3ee9ec3448e6b79c5d93aedd21',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/3eab44b9-af35-4512-9a70-5ff509a35ec6/3eab44b9-af35-4512-9a70-5ff509a35ec6.vep.vcf.gz',
#                                                      'id': '3eab44b9-af35-4512-9a70-5ff509a35ec6',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '3eab44b9-af35-4512-9a70-5ff509a35ec6'}],
#                                                      'label': '3eab44b9-af35-4512-9a70-5ff509a35ec6.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 339485985,
#                                                      'checksum': '1a754f4990fdebbd44ecf09d41b9866c',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Aggregated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/4683fdc3-2041-4b03-9886-fd035ab64c4f/TCGA.OV.somaticsniper.4683fdc3-2041-4b03-9886-fd035ab64c4f.DR-10.0.protected.maf.gz',
#                                                      'id': '4683fdc3-2041-4b03-9886-fd035ab64c4f',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '4683fdc3-2041-4b03-9886-fd035ab64c4f'}],
#                                                      'label': 'TCGA.OV.somaticsniper.4683fdc3-2041-4b03-9886-fd035ab64c4f.DR-10.0.protected.maf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 228635,
#                                                      'checksum': '70fbf807bde3ed92718f77fd605d6286',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/46ebb46b-4d4b-4378-8fe3-0d202f299ddf/46ebb46b-4d4b-4378-8fe3-0d202f299ddf.vcf.gz',
#                                                      'id': '46ebb46b-4d4b-4378-8fe3-0d202f299ddf',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '46ebb46b-4d4b-4378-8fe3-0d202f299ddf'}],
#                                                      'label': '46ebb46b-4d4b-4378-8fe3-0d202f299ddf.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 999885,
#                                                      'checksum': 'f015a8ec5602c71e61255edbc5b69ad5',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/48d00e33-46f7-4936-9631-4b02fdffd4d2/48d00e33-46f7-4936-9631-4b02fdffd4d2.vep.vcf.gz',
#                                                      'id': '48d00e33-46f7-4936-9631-4b02fdffd4d2',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '48d00e33-46f7-4936-9631-4b02fdffd4d2'}],
#                                                      'label': '48d00e33-46f7-4936-9631-4b02fdffd4d2.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 9334333,
#                                                      'checksum': 'fe3f8b0a78a89c60c3e4e8fe29974030',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Masked '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-open/51423d79-e9c5-4c4d-b12c-99c1338dbd43/TCGA.OV.muse.51423d79-e9c5-4c4d-b12c-99c1338dbd43.DR-10.0.somatic.maf.gz',
#                                                      'id': '51423d79-e9c5-4c4d-b12c-99c1338dbd43',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '51423d79-e9c5-4c4d-b12c-99c1338dbd43'}],
#                                                      'label': 'TCGA.OV.muse.51423d79-e9c5-4c4d-b12c-99c1338dbd43.DR-10.0.somatic.maf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 150317,
#                                                      'checksum': 'be963d2c0c04e1dfa05970af8e9b0d0f',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/520f77ea-34fb-4742-9eaf-95caca8cd4f4/520f77ea-34fb-4742-9eaf-95caca8cd4f4.vep.vcf.gz',
#                                                      'id': '520f77ea-34fb-4742-9eaf-95caca8cd4f4',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '520f77ea-34fb-4742-9eaf-95caca8cd4f4'}],
#                                                      'label': '520f77ea-34fb-4742-9eaf-95caca8cd4f4.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 188183,
#                                                      'checksum': 'f7904b286f4a6a59fdb9652677440c8f',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/5e7759ef-ff6a-4ec4-a4e1-24632d7c5ea7/5e7759ef-ff6a-4ec4-a4e1-24632d7c5ea7.vcf',
#                                                      'id': '5e7759ef-ff6a-4ec4-a4e1-24632d7c5ea7',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '5e7759ef-ff6a-4ec4-a4e1-24632d7c5ea7'}],
#                                                      'label': '5e7759ef-ff6a-4ec4-a4e1-24632d7c5ea7.vcf',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 552226,
#                                                      'checksum': '96531472cbf6b95b6011919225a344e0',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/661799e7-ee9d-4200-8fd6-cacdb044aaaf/661799e7-ee9d-4200-8fd6-cacdb044aaaf.vep.vcf.gz',
#                                                      'id': '661799e7-ee9d-4200-8fd6-cacdb044aaaf',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '661799e7-ee9d-4200-8fd6-cacdb044aaaf'}],
#                                                      'label': '661799e7-ee9d-4200-8fd6-cacdb044aaaf.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 3250133,
#                                                      'checksum': '01b85394968a8c47380288b8b80200cf',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/6a423b61-2b06-47b4-b5ce-c246d0c931c6/6a423b61-2b06-47b4-b5ce-c246d0c931c6.vep.vcf.gz',
#                                                      'id': '6a423b61-2b06-47b4-b5ce-c246d0c931c6',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '6a423b61-2b06-47b4-b5ce-c246d0c931c6'}],
#                                                      'label': '6a423b61-2b06-47b4-b5ce-c246d0c931c6.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 188353,
#                                                      'checksum': '1bb1abd748b42ff73e6066fce482bf8c',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/775087ae-7b91-4b47-9a02-acaf99a0d75a/775087ae-7b91-4b47-9a02-acaf99a0d75a.vcf',
#                                                      'id': '775087ae-7b91-4b47-9a02-acaf99a0d75a',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '775087ae-7b91-4b47-9a02-acaf99a0d75a'}],
#                                                      'label': '775087ae-7b91-4b47-9a02-acaf99a0d75a.vcf',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 2127727,
#                                                      'checksum': '32bc8d18d0f055bb342a812d3ef1c17c',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/81b4888b-3421-4506-8991-6401c0e65f39/81b4888b-3421-4506-8991-6401c0e65f39.vcf',
#                                                      'id': '81b4888b-3421-4506-8991-6401c0e65f39',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '81b4888b-3421-4506-8991-6401c0e65f39'}],
#                                                      'label': '81b4888b-3421-4506-8991-6401c0e65f39.vcf',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 1823867,
#                                                      'checksum': '8c6e9de2e69240551e8ff406e8c5ab77',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/861d302c-8333-45d0-b950-44bc657a6932/861d302c-8333-45d0-b950-44bc657a6932.vcf',
#                                                      'id': '861d302c-8333-45d0-b950-44bc657a6932',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '861d302c-8333-45d0-b950-44bc657a6932'}],
#                                                      'label': '861d302c-8333-45d0-b950-44bc657a6932.vcf',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 31626378797,
#                                                      'checksum': '0e86c2784a4bc4c1f88bbdd0fa4cbac9',
#                                                      'data_category': 'Sequencing '
#                                                                       'Reads',
#                                                      'data_type': 'Aligned '
#                                                                   'Reads',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/8a0776b8-326e-4fce-b613-1ef5bf33d7bc/C239.TCGA-09-0369-10C-01W.6_gdc_realn.bam',
#                                                      'id': '8a0776b8-326e-4fce-b613-1ef5bf33d7bc',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '8a0776b8-326e-4fce-b613-1ef5bf33d7bc'}],
#                                                      'label': 'C239.TCGA-09-0369-10C-01W.6_gdc_realn.bam',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 976199,
#                                                      'checksum': 'f818ebcd9031ff75e377209926198c66',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Annotated '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/8b992a61-5b22-472d-ad5a-369da46f24dd/8b992a61-5b22-472d-ad5a-369da46f24dd.vep.vcf.gz',
#                                                      'id': '8b992a61-5b22-472d-ad5a-369da46f24dd',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '8b992a61-5b22-472d-ad5a-369da46f24dd'}],
#                                                      'label': '8b992a61-5b22-472d-ad5a-369da46f24dd.vep.vcf.gz',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 2098261,
#                                                      'checksum': 'bb97a6347e8fb5b88dc40d1cf9b4ebcc',
#                                                      'data_category': 'Simple '
#                                                                       'Nucleotide '
#                                                                       'Variation',
#                                                      'data_type': 'Raw Simple '
#                                                                   'Somatic '
#                                                                   'Mutation',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-controlled/8decd013-c8bf-4764-97b5-4500f96da86e/8decd013-c8bf-4764-97b5-4500f96da86e.vcf',
#                                                      'id': '8decd013-c8bf-4764-97b5-4500f96da86e',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '8decd013-c8bf-4764-97b5-4500f96da86e'}],
#                                                      'label': '8decd013-c8bf-4764-97b5-4500f96da86e.vcf',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 17404,
#                                                      'checksum': 'c3fbf663fddd903b8558465d10990cac',
#                                                      'data_category': 'Copy '
#                                                                       'Number '
#                                                                       'Variation',
#                                                      'data_type': 'Allele-specific '
#                                                                   'Copy Number '
#                                                                   'Segment',
#                                                      'file_format': None,
#                                                      'gcs_path': 'gs://gdc-tcga-phs000178-open/907afc77-83e1-4a8a-9b5b-b17f7593c802/TCGA-OV.0ae9f973-4f93-48f0-a214-35d671d46fef.ascat2.allelic_specific.seg.txt',
#                                                      'id': '907afc77-83e1-4a8a-9b5b-b17f7593c802',
#                                                      'identifier': [ { 'system': 'GDC',
#                                                                        'value': '907afc77-83e1-4a8a-9b5b-b17f7593c802'}],
#                                                      'label': 'TCGA-OV.0ae9f973-4f93-48f0-a214-35d671d46fef.ascat2.allelic_specific.seg.txt',
#                                                      'type': None},
#                                                    { 'associated_project': [ 'TCGA-OV'],
#                                                      'byte_size': 2836399,
#                                                      'checksum': 'da583de560364d8aca4722f6be6df20c',
# ...
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'analyte'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '41982e47-9e0f-4cda-bc47-01fbe6d07906',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '11197914-6f55-4542-9138-ad6b451c3350',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '11197914-6f55-4542-9138-ad6b451c3350'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '41982e47-9e0f-4cda-bc47-01fbe6d07906',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '3958b986-c1dd-49ff-8c15-74b077705273',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '3958b986-c1dd-49ff-8c15-74b077705273'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '41982e47-9e0f-4cda-bc47-01fbe6d07906',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '6f0454ce-c0b5-4397-80ae-d25034f6b8b7',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '6f0454ce-c0b5-4397-80ae-d25034f6b8b7'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '41982e47-9e0f-4cda-bc47-01fbe6d07906',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '77a8b044-fe4f-4937-a86c-b98912a06dc1',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '77a8b044-fe4f-4937-a86c-b98912a06dc1'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '41982e47-9e0f-4cda-bc47-01fbe6d07906',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '1f972766-2f58-4d41-b84c-3493ef2dd0c4',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '1f972766-2f58-4d41-b84c-3493ef2dd0c4'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '48aab2c5-1ac0-42c5-84c8-97fd245bf6e2',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '35c29a23-8258-42e7-9abf-ae8a61ad5dc4',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '35c29a23-8258-42e7-9abf-ae8a61ad5dc4'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'analyte'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '35c29a23-8258-42e7-9abf-ae8a61ad5dc4',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'edce285a-f976-4731-9205-73df82a93904',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'edce285a-f976-4731-9205-73df82a93904'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '48aab2c5-1ac0-42c5-84c8-97fd245bf6e2',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'b9ed248d-6331-4eb8-801e-2661f3cdf4e8',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'b9ed248d-6331-4eb8-801e-2661f3cdf4e8'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'analyte'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'b9ed248d-6331-4eb8-801e-2661f3cdf4e8',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '04427ef8-eb09-4a4a-a057-f93974010e9b',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '04427ef8-eb09-4a4a-a057-f93974010e9b'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'b9ed248d-6331-4eb8-801e-2661f3cdf4e8',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '633f5c4d-c224-404c-9f68-24daafd1fc84',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '633f5c4d-c224-404c-9f68-24daafd1fc84'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'b9ed248d-6331-4eb8-801e-2661f3cdf4e8',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'a8ed0a01-c437-4499-9bdd-90c77dbc9684',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'a8ed0a01-c437-4499-9bdd-90c77dbc9684'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': '48aab2c5-1ac0-42c5-84c8-97fd245bf6e2',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'f09572d2-52ed-4026-9218-8e027897c784'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'analyte'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '0ae9f973-4f93-48f0-a214-35d671d46fef',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '0ae9f973-4f93-48f0-a214-35d671d46fef'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'c743ca6b-55f0-4f28-827e-f7781ab68b6b',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'c743ca6b-55f0-4f28-827e-f7781ab68b6b'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'ed02808f-48b1-47a9-8eb3-8ab7c0c13ee2',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'ed02808f-48b1-47a9-8eb3-8ab7c0c13ee2'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '4d46ab44-070e-4731-be4a-ad90c1f90b96',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '4d46ab44-070e-4731-be4a-ad90c1f90b96'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '955cd230-3848-4275-af94-d2bfc753a843',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '955cd230-3848-4275-af94-d2bfc753a843'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'dcd6efd5-6999-4bf7-9aea-be9f191b42fa',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'dcd6efd5-6999-4bf7-9aea-be9f191b42fa'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': '48262fd0-9569-4d22-918f-ddaa6ac8c215',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': '48262fd0-9569-4d22-918f-ddaa6ac8c215'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'},
#                 { 'File': [],
#                   'age_at_collection': None,
#                   'anatomical_site': None,
#                   'associated_project': 'TCGA-OV',
#                   'derived_from_specimen': 'f09572d2-52ed-4026-9218-8e027897c784',
#                   'derived_from_subject': 'TCGA-09-0369',
#                   'id': 'b0b1c430-df80-4cb5-9491-05f680fb6853',
#                   'identifier': [ { 'system': 'GDC',
#                                     'value': 'b0b1c430-df80-4cb5-9491-05f680fb6853'}],
#                   'primary_disease_type': 'Cystic, Mucinous and Serous '
#                                           'Neoplasms',
#                   'source_material_type': 'Primary Tumor',
#                   'specimen_type': 'aliquot'}],
#   'Treatment': [ {'outcome': None, 'type': 'Radiation Therapy, NOS'},
#                  {'outcome': None, 'type': 'Pharmaceutical Therapy, NOS'}],
#   'age_at_diagnosis': 20705,
#   'associated_project': 'TCGA-OV',
#   'days_to_birth': -20705,
#   'ethnicity': 'not hispanic or latino',
#   'id': '2ccc9ded-6131-5138-ac74-27f15e75a761',
#   'identifier': [ { 'system': 'GDC',
#                     'value': '1d9893c8-0de3-4b07-b0ba-a53019b23eb4'}],
#   'morphology': '8441/3',
#   'primary_diagnosis': 'Serous cystadenocarcinoma, NOS',
#   'primary_disease_site': 'Ovary',
#   'primary_disease_type': 'Cystic, Mucinous and Serous Neoplasms',
#   'race': 'white',
#   'sex': 'female',
#   'tumor_grade': 'not reported',
#   'tumor_stage': 'not reported'}
